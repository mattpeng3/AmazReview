# %%
import pandas as pd

# %%
elect_data = pd.read_json('/Users/mattpeng/Desktop/github/AmazReview/data_sets/electronics.json', lines = True)
del elect_data['asin']
del elect_data['reviewerID']
del elect_data['reviewerName']
del elect_data['reviewTime']
del elect_data['unixReviewTime']

# %%
elect_data
# Out:
#           helpful  overall                                         reviewText  \
# 0          [0, 0]        5  We got this GPS for my husband who is an (OTR)...
# 1        [12, 15]        1  I'm a professional OTR truck driver, and I bou...
# 2        [43, 45]        3  Well, what can I say.  I've had this unit in m...
# 3         [9, 10]        2  Not going to write a long review, even thought...
# 4          [0, 0]        1  I've had mine for a year and here's what we go...
# 5          [3, 3]        5  I am using this with a Nook HD+. It works as d...
# 6          [0, 0]        2  The cable is very wobbly and sometimes disconn...
# 7          [0, 0]        5  This adaptor is real easy to setup and use rig...
# 8          [0, 0]        4  This adapter easily connects my Nook HD 7&#34;...
# 9          [3, 3]        5  This product really works great but I found th...
# 10         [2, 2]        4  This item is just as was described in the orig...
# ...
