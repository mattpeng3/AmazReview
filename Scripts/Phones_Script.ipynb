# %%
import pandas as pd

# %%
phone_data = pd.read_csv('/Users/mattpeng/Desktop/github/AmazReview/data_sets/Phones.csv')
del phone_data['Product Name']
del phone_data['Brand Name']
del phone_data['Price']

# %%
phone_data
# Out:
#         Rating                                            Reviews  \
# 0            5  I feel so LUCKY to have found this used (phone...
# 1            4  nice phone, nice up grade from my pantach revu...
# 2            5                                       Very pleased
# 3            4  It works good but it goes slow sometimes but i...
# 4            4  Great phone to replace my lost phone. The only...
# 5            1  I already had a phone with problems... I know ...
# 6            2  The charging port was loose. I got that solder...
# 7            2  Phone looks good but wouldn't stay charged, ha...
# 8            5  I originally was using the Samsung S2 Galaxy f...
# 9            3  It's battery life is great. It's very responsi...
# 10           3  My fiance had this phone previously, but cause...
# 11           5  This is a great product it came after two days...
# 12           5  These guys are the best! I had a little situat...
# ...

# %%
phone = phone_data

# %%
five= phone.where(cond =(phone['Rating']==5)).dropna()
four=phone.where(cond =(phone['Rating']==4)).dropna()
three= phone.where(cond =(phone['Rating']==3)).dropna()
two=phone.where(cond =(phone['Rating']==2)).dropna()
one=phone.where(cond =(phone['Rating']==1)).dropna()

# %%
one['Reviews'].to_csv('one.csv')
two['Reviews'].to_csv('two.csv')
three['Reviews'].to_csv('three.csv')
four['Reviews'].to_csv('four.csv')
five['Reviews'].to_csv('five.csv')

# %%
#one star
132072 the
111972 I
90699 it
84905 phone
83119 and
83075 to
73122 a
48535 not
47864 is
41006 this
39122 was
33404 of
33112 t
31297 for
28449 that
27944 on
27445 in
26944 with
25134 my
21077 The
20245 but
20147 have
16786 you
15133 It
15108 me
14415 work
14246 had
13393 s
13371 as
12700 i
12619 be
12115 from
12089 one
11628 no
11497 screen
11381 so
11322 can
11319 or
11234 would
11233 This
10851 all
10843 they
10643 get
9944 at
9852 when
9825 will
9579 battery
9451 back
9303 very
9169 after
9113 use
8971 just
8876 out
8854 an
8781 has
8592 up
8577 buy
8572 only
8526 new
8465 even
8234 time
7883 bought
7641 like
7629 because
7332 are
7222 if
7168 money
7021 working
7018 do
6796 did
6772 am
6754 off
6653 return
6562 good
6509 product
6471 got
5914 months
5860 now
5805 does
5700 card
5619 what
5544 about
5510 charge
5441 could
5436 don
5359 unlocked
5276 phones
5189 seller
5084 never
5044 m
4957 then
4773 problem
4770 any
4763 Phone
4757 by
4747 which
4678 T
4630 doesn
4557 been
4544 bad

# %%
#two star
65211 the
48731 I
39644 it
39483 to
37089 and
34884 phone
34257 a
25577 is
17972 not
16295 this
16257 for
15797 of
15402 was
13684 that
13417 t
13220 with
12777 in
12740 on
12548 but
11442 The
11093 my
10202 have
9117 you
7672 s
7046 as
6944 It
6874 be
6784 had
5798 or
5654 so
5603 screen
5453 can
5329 me
5225 would
5137 one
4930 battery
4909 very
4807 all
4735 use
4731 when
4660 just
4553 get
4538 good
4526 has
4526 are
4498 work
4452 from
4419 no
4389 at
4376 like
4297 i
4144 up
4115 an
4001 if
3965 out
3895 will
3830 only
3697 This
3514 about
3504 because
3456 time
3399 they
3349 back
3253 new
3133 after
3094 even
2935 off
2797 am
2787 do
2717 really
2712 great
2674 other
2614 than
2568 phones
2566 which
2553 what
2530 camera
2522 does
2516 more
2507 its
2507 did
2501 don
2496 got
2417 there
2395 card
2384 m
