# %%
import pandas as pd
import operator

# %%
#pandas to read csv file
baby_data = pd.read_json("baby.json", lines =True)

# %%
del baby_data['asin']
del baby_data['reviewerID']
del baby_data['reviewerName']
del baby_data['reviewTime']
del baby_data['unixReviewTime']
del baby_data['helpful']
del baby_data['summary']

# %%
baby_one = baby_data.loc[baby_data['overall'] == 1]
baby_two = baby_data.loc[baby_data['overall'] == 2]
baby_three = baby_data.loc[baby_data['overall'] == 3]
baby_four = baby_data.loc[baby_data['overall'] == 4]
baby_five = baby_data.loc[baby_data['overall'] == 5]

# %%
commonWords = ['the', 'be', 'to', 'of', 'and', 'a', 'in', 'that', 'have',
              'i', 'it', 'for', 'not', 'on', 'with', 'he', 'as', 'you',
              'do', 'at', 'this', 'but', 'his', 'by', 'from', 'they', 'we',
              'say', 'her', 'she', 'or', 'will', 'an', 'my', 'one', 'all',
              'would', 'there', 'their', 'what', 'so', 'up', 'out', 'if',
              'about', 'who', 'get', 'which', 'go', 'when', 'me', 'make',
              'can', 'like', 'time', 'no', 'just', 'him', 'know', 'take',
              'person', 'into', 'year', 'your', 'good', 'some', 'could',
              'them', 'see', 'other', 'than', 'then', 'now', 'look', 'only',
              'come', 'its', "it's", 'over', 'think', 'also', 'back', 'after',
              'use', 'two', 'how', 'our', 'work', 'first', 'well', 'way', 'even',
              'new', 'want', 'because', 'any', 'these', 'give', 'day', 'most', 'us',
               'who'
    ]

# %%
#### deletes the symbols out of the words for instance such as . and '
def del_sym(txt):
    del_symbols = ['.', "'", "!", "@", "#", "$", "%", "^", "&", "*", "(", ")", "{", "}",
                       "1", "2", "3", "4", "5", "6", "7", "8", "9", ":", ";", "<", ">", "?",
                       ",", "[", "]", "-", "_", "+", "="
                  ]
     
    i = 0
    while i < len(txt):
        if txt[i] in del_symbols:
            txt = txt[0:i] + txt[i+1:]
            i-=1
        i+=1
    return txt
    

#uncomment below to test function
#word = "hi''.a"
#words = "he344o&*o"
#del_sym(word)  
#del_sym(words)

# %%
def addText(dataTable):
    sentence = ""
    for i in range(dataTable.shape[0]):
        word = str(dataTable.iloc[i]["reviewText"])
        sentence += " " + word
    return sentence

def deleteCommon(str):
    sentence = ""
    conden = str.split(" ")
    for i in range(len(conden)):
        if conden[i].lower() not in commonWords:
            sentence += " " + conden[i]
    return sentence

def rewriteText(dataTable):
    allData = deleteCommon(addText(dataTable))
    allDataSplit = allData.split(" ")
    d = {}
    for i in range(len(allDataSplit)):
        if allDataSplit[i] not in d:
            d[allDataSplit[i]] = 1
        else:
            d[allDataSplit[i]] += 1
            
    sorted_d = sorted(d.items(), key=operator.itemgetter(1), reverse=True)
    return sorted_d


one_text = rewriteText(baby_one)
two_text = rewriteText(baby_two)
three_text = rewriteText(baby_three)
four_text = rewriteText(baby_four)
five_text = rewriteText(baby_five)

# %%
one_text
# Out:
# [('', 14916),
#  ('is', 11216),
#  ('was', 7167),
#  ('are', 4160),
#  ('baby', 2954),
#  ('had', 2716),
#  ('very', 2162),
#  ('it.', 1881),
#  ('has', 1750),
#  ('really', 1598),
#  ("don't", 1595),
#  ('too', 1546),
#  ('more', 1534),
#  ('bought', 1430),
#  ('product', 1387),
#  ('much', 1375),
#  ('were', 1358),
#  ('put', 1329),
#  ('off', 1327),
#  ("didn't", 1236),
#  ('got', 1209),
#  ('seat', 1146),
#  ('-', 1142),
#  ("doesn't", 1116),
#  ('little', 1107),
#  ('used', 1094),
#  ('did', 1058),
#  ('using', 1055),
#  ('son', 1055),
#  ("I'm", 1041),
#  ('old', 1038),
#  ('tried', 1023),
#  ('am', 1023),
#  ('buy', 981),
#  ('still', 968),
#  ('does', 967),
#  ('thing', 930),
#  ('been', 915),
#  ('fit', 862),
#  ('made', 852),
#  ("can't", 827),
#  ('better', 818),
#  ('never', 804),
#  ('it,', 802),
#  ('2', 798),
#  ('months', 789),
#  ('thought', 779),
#  ('plastic', 764),
#  ('waste', 757),
#  ('great', 754),
#  ('bottle', 753),
#  ('hard', 750),
#  ('few', 735),
#  ('something', 724),
#  ('down', 719),
#  ('before', 713),
#  ('daughter', 712),
#  ('going', 709),
#  ('bottles', 709),
#  ('around', 707),
#  ('money', 704),
#  ('diaper', 690),
#  ('since', 682),
#  ('monitor', 675),
#  ('car', 664),
#  ('reviews', 658),
#  ('same', 650),
#  ('cup', 642),
#  ('recommend', 641),
#  ('keep', 639),
#  ('right', 637),
#  ('through', 630),
#  ('while', 629),
#  ('child', 627),
#  ('month', 623),
#  ('should', 622),
#  ('enough', 618),
#  ('another', 613),
#  ('need', 610),
#  ('water', 597),
#  ('try', 582),
#  ('every', 578),
#  ('return', 575),
#  ('3', 574),
#  ('milk', 568),
#  ('top', 564),
#  ('small', 551),
#  ('getting', 549),
#  ('without', 546),
#  ('bag', 541),
#  ('hold', 539),
#  ('purchased', 530),
#  ('sure', 529),
#  ('able', 524),
#  ("I've", 522),
#  ('different', 522),
#  ('actually', 517),
#  ('being', 510),
#  ('find', 503),
#  ('where', 502),
#  ('big', 491),
#  ('found', 487),
#  ('pump', 486),
#  ("baby's", 480),
#  ('many', 477),
#  ('love', 470),
#  ('side', 466),
#  ('stroller', 463),
#  ('money.', 456),
#  ('all.', 456),
#  ('them.', 454),
#  ('item', 451),
#  ('trying', 446),
#  ('easy', 441),
#  ('came', 440),
#  ('started', 439),
#  ('wanted', 437),
#  ('worth', 435),
#  ('part', 435),
#  ('out.', 428),
#  ("wouldn't", 427),
#  ('times', 426),
#  ('product.', 424),
#  ('read', 424),
#  ('long', 424),
#  ('completely', 420),
#  ('both', 419),
#  ('quality', 417),
#  ('cover', 414),
#  ('&', 413),
#  ('returned', 412),
#  ('4', 407),
#  ('went', 403),
#  ('open', 402),
#  ('bad', 400),
#  ('lot', 399),
#  ('stay', 398),
#  ('having', 397),
#  ('ended', 395),
#  ('until', 394),
#  ('anything', 394),
#  ('5', 394),
#  ('pretty', 391),
#  ('makes', 390),
#  ('took', 390),
#  ('piece', 387),
#  ('away', 386),
#  ("won't", 383),
#  ('set', 383),
#  ("couldn't", 382),
#  ('high', 381),
#  ('bottom', 377),
#  ('under', 374),
#  ('once', 372),
#  ('toy', 369),
#  ('worked', 368),
#  ('always', 366),
#  ('looking', 356),
#  ('almost', 355),
#  ('clean', 354),
#  ("wasn't", 354),
#  ('problem', 350),
#  ('chair', 346),
#  ('buying', 345),
#  ('cheap', 345),
#  ('cups', 343),
#  ('size', 342),
#  ('head', 342),
#  ('less', 337),
#  ('wish', 336),
#  ('things', 333),
#  ('last', 332),
#  ('food', 332),
#  ('1', 329),
#  ("isn't", 329),
#  ('gets', 329),
#  ('husband', 328),
#  ('feel', 326),
#  ('already', 325),
#  ('works', 325),
#  ('nipple', 324),
#  ('suction', 324),
#  ('ordered', 324),
#  ('room', 322),
#  ('this.', 320),
#  ('fabric', 320),
#  ('disappointed', 319),
#  ('Amazon', 317),
#  ('leak', 317),
#  ('received', 314),
#  ('design', 313),
#  ('one.', 313),
#  ('second', 312),
#  ('looks', 312),
#  ('gate', 312),
#  ('why', 311),
#  ('difficult', 311),
#  ('nice', 311),
#  ('seems', 310),
#  ('stick', 307),
#  ('maybe', 307),
#  ('wash', 305),
#  ('weeks', 304),
#  ('comes', 303),
#  ('turn', 303),
#  ('pull', 301),
#  ('far', 298),
#  ('easily', 298),
#  ('might', 298),
#  ('pillow', 298),
#  ('However,', 296),
#  ('whole', 296),
#  ("Don't", 295),
#  ('off.', 295),
#  ('baby.', 292),
#  ('least', 291),
#  ('cannot', 291),
#  ('several', 291),
#  ('babies', 290),
#  ('may', 289),
#  ('mattress', 289),
#  ('6', 287),
#  ('gave', 286),
#  ('between', 284),
#  ("I'd", 283),
#  ('inside', 282),
#  ('those', 281),
#  ('time.', 281),
#  ('let', 279),
#  ('ones', 279),
#  ('such', 278),
#  ('crib', 277),
#  ('hand', 277),
#  ('nothing', 276),
#  ('idea', 275),
#  ('lid', 274),
#  ('work.', 274),
#  ('night', 274),
#  ('Also,', 273),
#  ('decided', 272),
#  ('bit', 270),
#  ('each', 269),
#  ('soft', 267),
#  ('stuck', 265),
#  ('place', 264),
#  ('stopped', 264),
#  ('tray', 264),
#  ('couple', 263),
#  ('price', 263),
#  ('unit', 263),
#  ('smell', 262),
#  ("that's", 262),
#  ('said', 262),
#  ('toddler', 259),
#  ('instead', 258),
#  ('minutes', 257),
#  ('extra', 257),
#  ('on.', 256),
#  ('use.', 256),
#  ('Baby', 254),
#  ('again.', 254),
#  ('impossible', 253),
#  ('sit', 253),
#  ('end', 253),
#  ('straw', 253),
#  ('regular', 252),
#  ('straps', 252),
#  ("you're", 252),
#  ('diapers', 251),
#  ('material', 251),
#  ('though', 250),
#  ('seemed', 249),
#  ('purchase', 248),
#  ('people', 247),
#  ('company', 247),
#  ('sleep', 246),
#  ('play', 246),
#  ('sent', 246),
#  ('sound', 245),
#  ('definitely', 245),
#  ('next', 244),
#  ('me.', 244),
#  ('close', 243),
#  ('box', 243),
#  ('probably', 241),
#  ('kept', 241),
#  ('up.', 240),
#  ('own', 239),
#  ('brand', 239),
#  ('help', 238),
#  ('loved', 236),
#  ('kids', 236),
#  ('cloth', 236),
#  ('store', 235),
#  ('pad', 235),
#  ('seem', 235),
#  ('three', 235),
#  ('broke', 234),
#  ('supposed', 233),
#  ('ever', 233),
#  ('either', 232),
#  ('looked', 232),
#  ('review', 232),
#  ('order', 232),
#  ('making', 231),
#  ('within', 231),
#  ('working', 231),
#  ('putting', 230),
#  ('everything', 230),
#  ('again', 229),
#  ('matter', 228),
#  ('needed', 228),
#  ('infant', 228),
#  ('cute', 227),
#  ('well.', 226),
#  ('returning', 226),
#  ('10', 225),
#  ('products', 225),
#  ('wipes', 225),
#  ('brush', 225),
#  ('super', 224),
#  ('fall', 224),
#  ('air', 222),
#  ('thinking', 221),
#  ('Very', 220),
#  ('week', 220),
#  ('parts', 220),
#  ('noticed', 219),
#  ('half', 219),
#  ('washed', 217),
#  ('replacement', 216),
#  ('sippy', 216),
#  ('quite', 214),
#  ('left', 213),
#  ('nipples', 212),
#  ('front', 211),
#  ('customer', 211),
#  ('excited', 209),
#  ('light', 209),
#  ('longer', 208),
#  ('seat.', 208),
#  ('hear', 208),
#  ('handle', 207),
#  ('liked', 206),
#  ('guess', 205),
#  ('thin', 204),
#  ('toys', 203),
#  ('together', 201),
#  ('pieces', 201),
#  ('unless', 201),
#  ('strap', 201),
#  ('apart', 200),
#  ('tub', 200),
#  ('this,', 199),
#  ('large', 199),
#  ('move', 199),
#  ('older', 198),
#  ('bags', 198),
#  ('barely', 196),
#  ('picture', 195),
#  ('sitting', 195),
#  ('days', 194),
#  ('takes', 193),
#  ('hate', 193),
#  ('goes', 193),
#  ('changing', 192),
#  ('legs', 192),
#  ('kind', 192),
#  ('potty', 191),
#  ('issue', 191),
#  ('point', 190),
#  ('these.', 189),
#  ('finally', 188),
#  ('battery', 188),
#  ('else', 187),
#  ('extremely', 187),
#  ('needs', 187),
#  ('onto', 187),
#  ('poor', 187),
#  ('told', 186),
#  ('breast', 186),
#  ('fell', 185),
#  ('newborn', 185),
#  ('leaks', 184),
#  ('tight', 184),
#  ('change', 183),
#  ('door', 183),
#  ('opened', 182),
#  ('comfortable', 182),
#  ('called', 182),
#  ('spend', 180),
#  ('expensive', 180),
#  ('back.', 179),
#  ('8', 179),
#  ('hands', 178),
#  ('all,', 178),
#  ('coming', 178),
#  ('push', 177),
#  ('happy', 177),
#  ('turned', 177),
#  ('reading', 177),
#  ('pay', 177),
#  ('huge', 177),
#  ('hoping', 177),
#  ('years', 176),
#  ('must', 174),
#  ('safe', 173),
#  ('says', 173),
#  ('remove', 172),
#  ('fact', 172),
#  ('liquid', 172),
#  ('threw', 171),
#  ('mouth', 171),
#  ('them,', 171),
#  ('(and', 170),
#  ('send', 170),
#  ('safety', 169),
#  ('bath', 169),
#  ('reason', 169),
#  ('free', 168),
#  ('due', 167),
#  ('carrier', 167),
#  ('short', 166),
#  ('during', 166),
#  ('pain', 165),
#  ('especially', 165),
#  ('up,', 165),
#  ('others', 164),
#  ('instructions', 164),
#  ('felt', 164),
#  ('table', 163),
#  ('constantly', 163),
#  ('(which', 162),
#  ('house', 162),
#  ('middle', 162),
#  ('worst', 162),
#  ('out,', 161),
#  ('Maybe', 161),
#  ('entire', 159),
#  ('pack', 159),
#  ('time,', 158),
#  ('fine', 158),
#  ('music', 158),
#  ('cut', 157),
#  ('start', 157),
#  ('kid', 157),
#  ('hot', 156),
#  ('against', 156),
#  ('soon', 156),
#  ('horrible', 156),
#  ('immediately', 156),
#  ('service', 156),
#  ('absolutely', 155),
#  ('dry', 155),
#  ('better.', 155),
#  ('loves', 155),
#  ('disappointed.', 155),
#  ('swing', 154),
#  ("I'll", 154),
#  ('full', 154),
#  ('star', 154),
#  ('figured', 153),
#  ('throw', 153),
#  ('forward', 153),
#  ('baby,', 153),
#  ('Avent', 152),
#  ('weight', 152),
#  ('color', 152),
#  ('it!', 151),
#  ('holding', 151),
#  ('problems', 151),
#  ('(I', 150),
#  ('mirror', 150),
#  ('useless.', 149),
#  ('base', 149),
#  ('someone', 149),
#  ('means', 148),
#  ('parent', 148),
#  ('Medela', 148),
#  ('opening', 147),
#  ('off,', 147),
#  ('best', 147),
#  ('believe', 147),
#  ('stand', 146),
#  ('rather', 146),
#  ('simply', 146),
#  ('tiny', 146),
#  ('useless', 146),
#  ('latch', 145),
#  ('easier', 144),
#  ('replace', 144),
#  ('holes', 144),
#  ('instead.', 144),
#  ('toilet', 144),
#  ('white', 144),
#  ('washing', 143),
#  ('tell', 142),
#  ('face', 142),
#  ('leaked', 142),
#  ('screw', 141),
#  ('flimsy', 141),
#  ('cleaning', 141),
#  ('us.', 141),
#  ('uncomfortable', 140),
#  ('seat,', 140),
#  ('amount', 140),
#  ('--', 140),
#  ("they're", 139),
#  ('doing', 139),
#  ('perfect', 139),
#  ('flat', 139),
#  ('falling', 139),
#  ('home', 138),
#  ('here', 138),
#  ('itself', 138),
#  ('designed', 138),
#  ('months.', 137),
#  ('fits', 137),
#  ('real', 137),
#  ('in.', 137),
#  ('bottle.', 136),
#  ('realized', 136),
#  ('blue', 136),
#  ('hated', 135),
#  ('away.', 135),
#  ('hours', 135),
#  ('save', 134),
#  ('totally', 133),
#  ('lock', 132),
#  ('hole', 131),
#  ('me,', 131),
#  ('saw', 131),
#  ('pulled', 131),
#  ('yourself', 131),
#  ('falls', 131),
#  ('too.', 131),
#  ('paid', 130),
#  ('cause', 130),
#  ('mat', 130),
#  ('drink', 130),
#  ("haven't", 129),
#  ('pumping', 129),
#  ('bottles.', 129),
#  ('wrong', 129),
#  ('support', 129),
#  ('on,', 128),
#  ('standard', 128),
#  ('taking', 128),
#  ('Save', 128),
#  ('deal', 128),
#  ('given', 128),
#  ('reviewers', 128),
#  ('attached', 128),
#  ('pads', 128),
#  ('leave', 127),
#  ('old.', 127),
#  ('floor', 127),
#  ('warmer', 127),
#  ("there's", 127),
#  ('care', 127),
#  ('low', 127),
#  ('items', 127),
#  ('sheet', 126),
#  ('there.', 126),
#  ('Dr.', 126),
#  ('product,', 126),
#  ('spent', 126),
#  ('one,', 126),
#  ('single', 125),
#  ('yet', 125),
#  ('position', 124),
#  ('leaking', 124),
#  ('bed', 123),
#  ('thing.', 123),
#  ('camera', 123),
#  ("son's", 122),
#  ('well,', 122),
#  ('quickly', 122),
#  ('sides', 122),
#  ('problem.', 122),
#  ('giving', 122),
#  ('spout', 122),
#  ('figure', 121),
#  ('either.', 121),
#  ('months,', 121),
#  ('noise', 121),
#  ("aren't", 121),
#  ('rest', 121),
#  ('covers', 120),
#  ('original', 120),
#  ('Unfortunately,', 120),
#  ('warm', 120),
#  ('reviews.', 120),
#  ('heavy', 120),
#  ('use,', 119),
#  ('stuff', 119),
#  ('properly', 119),
#  ('Graco', 118),
#  ('So,', 118),
#  ('metal', 118),
#  ('terrible', 118),
#  ('case', 118),
#  ('literally', 117),
#  ('sounds', 117),
#  ('feet', 117),
#  ('mine', 117),
#  ('9', 117),
#  ('clear', 117),
#  ('batteries', 117),
#  ('near', 116),
#  ('strong', 116),
#  ('7', 116),
#  ('place.', 116),
#  ('annoying', 116),
#  ('space', 116),
#  ('wet', 116),
#  ('stop', 115),
#  ('children', 115),
#  ('that,', 114),
#  ('poorly', 114),
#  ('sheets', 113),
#  ('nearly', 113),
#  ('great.', 113),
#  ('feeding', 113),
#  ('cheaper', 113),
#  ('model', 113),
#  ('button', 112),
#  ('rubber', 112),
#  ('30', 111),
#  ('glass', 111),
#  ('smaller', 111),
#  ('shape', 111),
#  ('Since', 111),
#  ('straight', 111),
#  ('keeps', 111),
#  ('cup.', 111),
#  ('purchasing', 110),
#  ('loud', 110),
#  ('cost', 110),
#  ('total', 110),
#  ('type', 110),
#  ('velcro', 110),
#  ('neck', 109),
#  ('installed', 109),
#  ('broken', 109),
#  ('cold', 109),
#  ('loose', 109),
#  ('arms', 109),
#  ('shower', 108),
#  ('snap', 108),
#  ('now.', 108),
#  ('actual', 108),
#  ('wide', 108),
#  ('done', 108),
#  ('flow', 108),
#  ('feels', 108),
#  ('nursing', 108),
#  ('description', 108),
#  ('system', 107),
#  ('trash', 107),
#  ('slide', 107),
#  ('understand', 107),
#  ('package', 107),
#  ('seats', 107),
#  ('blanket', 107),
#  ('Munchkin', 106),
#  ('outside', 106),
#  ('suck', 106),
#  ('imagine', 106),
#  ('arrived', 106),
#  ('15', 105),
#  ('attach', 105),
#  ('20', 105),
#  ('foam', 104),
#  ('normal', 104),
#  ('silicone', 104),
#  ('that.', 104),
#  ('contacted', 104),
#  ('call', 104),
#  ('mobile', 104),
#  ("he's", 103),
#  ('Well,', 103),
#  ('slightly', 103),
#  ('bulky', 103),
#  ('not.', 103),
#  ('anyone', 103),
#  ('main', 103),
#  ('video', 103),
#  ('held', 103),
#  ('sometimes', 102),
#  ('sleeping', 102),
#  ('check', 102),
#  ('basically', 102),
#  ('myself', 102),
#  ('fold', 102),
#  ('version', 102),
#  ('reviews,', 102),
#  ('insert', 102),
#  ('dont', 101),
#  ('defective', 101),
#  ('While', 100),
#  ('bag.', 100),
#  ('clean.', 100),
#  ('gift', 100),
#  ('except', 100),
#  ('hope', 100),
#  ('bigger', 100),
#  ('stroller.', 99),
#  ('exactly', 99),
#  ('thick', 99),
#  ('heard', 99),
#  ('packaging', 99),
#  ('quality.', 99),
#  ('carry', 99),
#  ('issues', 99),
#  ('parents', 98),
#  ('born', 98),
#  ('work,', 98),
#  ('usually', 98),
#  ('often', 97),
#  ('highly', 97),
#  ('double', 97),
#  ('line', 97),
#  ('zipper', 97),
#  ('monitor.', 97),
#  ('body', 96),
#  ('reach', 96),
#  ("child's", 96),
#  ('VERY', 96),
#  ('mind', 96),
#  ('ring', 96),
#  ('him.', 96),
#  ('her.', 96),
#  ('however', 96),
#  ('(the', 96),
#  ('etc.', 96),
#  ('Britax', 96),
#  ('bib', 96),
#  ('money,', 95),
#  ('pail', 95),
#  ('knew', 95),
#  ('small.', 95),
#  ('Too', 95),
#  ('pee', 95),
#  ('four', 95),
#  ('lost', 95),
#  ('wear', 95),
#  ('item.', 95),
#  ('lasted', 94),
#  ('bottles,', 94),
#  ('allow', 94),
#  ('hassle', 94),
#  ('break', 94),
#  ('holds', 94),
#  ('however,', 94),
#  ('cotton', 93),
#  ('gotten', 93),
#  ('pacifier', 93),
#  ('later', 93),
#  ('in,', 93),
#  ('based', 93),
#  ('spoon', 93),
#  ('facing', 93),
#  ('secure', 92),
#  ('install', 92),
#  ('toy.', 92),
#  ('down.', 92),
#  ('Playtex', 92),
#  ('else.', 92),
#  ('mouth.', 92),
#  ('machine', 92),
#  ('multiple', 91),
#  ('behind', 91),
#  ('window', 91),
#  ('simple', 91),
#  ('hit', 91),
#  ('formula', 91),
#  ('positive', 91),
#  ('Diaper', 90),
#  ('pressure', 90),
#  ('wood', 90),
#  ('purpose', 90),
#  ('sun', 90),
#  ('happened', 90),
#  ('wall', 90),
#  ('monitors', 90),
#  ('replaced', 90),
#  ('clearly', 89),
#  ('life', 89),
#  ('live', 89),
#  ('shade', 89),
#  ('contact', 89),
#  ('motor', 89),
#  ('lights', 89),
#  ('amazon', 89),
#  ('screen', 89),
#  ('mess', 88),
#  ('fix', 88),
#  ('terrible.', 88),
#  ('along', 88),
#  ('leak.', 88),
#  ('idea,', 88),
#  ('colors', 88),
#  ('bowl', 88),
#  ('purchase.', 88),
#  ('temperature', 87),
#  ('down,', 87),
#  ('add', 87),
#  ('inches', 87),
#  ('wasted', 87),
#  ('volume', 87),
#  ('great,', 87),
#  ('uses', 86),
#  ('larger', 86),
#  ('child.', 86),
#  ('run', 86),
#  ('roll', 86),
#  ('area', 86),
#  ('everyone', 86),
#  ('screws', 86),
#  ('money!', 85),
#  ('back,', 85),
#  ('hang', 85),
#  ('Once', 85),
#  (':(', 85),
#  ('static', 85),
#  ('bar', 85),
#  ('fine.', 84),
#  ('these,', 84),
#  ('power', 84),
#  ('manual', 84),
#  ('again,', 84),
#  ('hurt', 84),
#  ('fill', 84),
#  ('bottle,', 84),
#  ('hospital', 84),
#  ('BPA', 84),
#  ('similar', 84),
#  ('become', 84),
#  ('adjust', 84),
#  ('arm', 83),
#  ('travel', 83),
#  ('past', 83),
#  ('old,', 83),
#  ('stars', 83),
#  ('worse', 83),
#  ('belt', 83),
#  ('cap', 83),
#  ('paint', 83),
#  ('pump.', 83),
#  ('likes', 83),
#  ('leg', 83),
#  ("daughter's", 82),
#  ('seconds', 82),
#  ('tip', 82),
#  ('water.', 82),
#  ('easily.', 82),
#  ('option', 82),
#  ('sending', 82),
#  ('anyway.', 81),
#  ('is,', 81),
#  ('dangerous', 81),
#  ('mom', 81),
#  ('didnt', 81),
#  ('hopes', 81),
#  ('over.', 81),
#  ('realize', 81),
#  ('anything.', 81),
#  ('phone', 81),
#  ('mold', 81),
#  ('holder', 81),
#  ('pulling', 80),
#  ('trouble', 80),
#  ('sits', 80),
#  ('clip', 80),
#  ('together.', 80),
#  ('touch', 80),
#  ('mention', 80),
#  ('twice', 80),
#  ('price.', 80),
#  ('cheaply', 80),
#  ('red', 80),
#  ('wipe', 80),
#  ('compared', 80),
#  ('black', 80),
#  ('working.', 80),
#  ('sell', 79),
#  ('followed', 79),
#  ('turns', 79),
#  ('although', 79),
#  ('expected', 79),
#  ('setting', 79),
#  ('experience', 79),
#  ('feature', 78),
#  ('handles', 78),
#  ("you'll", 78),
#  ('heat', 78),
#  ('per', 78),
#  ('fast', 78),
#  ('day.', 78),
#  ('prefer', 78),
#  ('number', 78),
#  ('shipping', 78),
#  ('organic', 78),
#  ('changed', 77),
#  ('Plus', 77),
#  ('now,', 77),
#  ('directions', 77),
#  ('thermometer', 77),
#  ('green', 77),
#  ('Fisher', 77),
#  ('known', 77),
#  ('caused', 77),
#  ('ripped', 77),
#  ('Waste', 77),
#  ('room.', 77),
#  ('pick', 77),
#  ('rough', 76),
#  ('rear', 76),
#  ('valve', 76),
#  ('lids', 76),
#  ('expect', 76),
#  ('course', 75),
#  ('fingers', 75),
#  ('pop', 75),
#  ('tub.', 75),
#  ('ago', 75),
#  ('bother', 75),
#  ("Brown's", 75),
#  ('wait', 75),
#  ('dirty', 75),
#  ('ready', 75),
#  ('level', 75),
#  ('100%', 74),
#  ('major', 74),
#  ('feed', 74),
#  ('foot', 74),
#  ('glad', 74),
#  ('night.', 74),
#  ('brand.', 74),
#  ('ends', 74),
#  ('negative', 74),
#  ('friend', 74),
#  ('wrap', 74),
#  ('dog', 74),
#  ('device', 73),
#  ('underneath', 73),
#  ('folded', 73),
#  ("she's", 73),
#  ("we've", 73),
#  ('plus', 73),
#  ('doesnt', 73),
#  ('adhesive', 73),
#  ('certainly', 73),
#  ('placed', 72),
#  ('suggest', 72),
#  ('sliding', 72),
#  ('sling', 72),
#  ('became', 72),
#  ('stupid', 72),
#  ("That's", 72),
#  ('burp', 72),
#  ('saying', 72),
#  ('milk.', 72),
#  ('keeping', 72),
#  ('basket', 72),
#  ('swaddle', 72),
#  ('complete', 71),
#  ('crib.', 71),
#  ('plugged', 71),
#  ('throwing', 71),
#  ('everywhere.', 71),
#  ('floor.', 71),
#  ('test', 71),
#  ('mean', 71),
#  ('crying', 71),
#  ('meant', 71),
#  ('you.', 71),
#  ('sold', 71),
#  ('smells', 70),
#  ('fun', 70),
#  ('waterproof', 70),
#  ('kitchen', 70),
#  ('Price', 70),
#  ('directly', 70),
#  ('storage', 70),
#  ('said,', 70),
#  ('Ergo', 70),
#  ('lay', 69),
#  ('Yes,', 69),
#  ('prevent', 69),
#  ('moved', 69),
#  ('chemical', 69),
#  ('perfectly', 69),
#  ('12', 69),
#  ('starts', 69),
#  ('sort', 69),
#  ('cups.', 69),
#  ('times.', 68),
#  ('around.', 68),
#  ...]

# %%
two_text
# Out:
# [('', 17977),
#  ('is', 15150),
#  ('was', 7836),
#  ('are', 5704),
#  ('baby', 4012),
#  ('very', 3169),
#  ('had', 3121),
#  ('really', 2649),
#  ('too', 2373),
#  ('it.', 2355),
#  ('has', 2295),
#  ('more', 2290),
#  ('much', 2197),
#  ("don't", 2192),
#  ('little', 1738),
#  ("doesn't", 1736),
#  ('bought', 1710),
#  ('were', 1677),
#  ('put', 1645),
#  ('-', 1599),
#  ("didn't", 1581),
#  ('seat', 1550),
#  ('off', 1495),
#  ('using', 1449),
#  ('son', 1448),
#  ("I'm", 1367),
#  ('used', 1350),
#  ('still', 1341),
#  ('does', 1325),
#  ('got', 1305),
#  ('did', 1278),
#  ('old', 1276),
#  ('fit', 1272),
#  ('product', 1224),
#  ('great', 1211),
#  ('am', 1195),
#  ('2', 1195),
#  ('better', 1174),
#  ('months', 1146),
#  ('around', 1076),
#  ('few', 1063),
#  ('been', 1048),
#  ('hard', 1042),
#  ('it,', 990),
#  ('enough', 976),
#  ('thought', 973),
#  ('since', 961),
#  ('made', 954),
#  ('daughter', 953),
#  ("can't", 943),
#  ('tried', 937),
#  ('buy', 934),
#  ('keep', 922),
#  ('while', 921),
#  ('thing', 920),
#  ('diaper', 908),
#  ('something', 905),
#  ('small', 902),
#  ('going', 866),
#  ('never', 865),
#  ('down', 857),
#  ('bottle', 855),
#  ('need', 854),
#  ('month', 825),
#  ('plastic', 812),
#  ('easy', 812),
#  ('before', 804),
#  ('love', 796),
#  ('cup', 789),
#  ('pretty', 784),
#  ('big', 781),
#  ('bottles', 781),
#  ('recommend', 780),
#  ('hold', 775),
#  ('bag', 772),
#  ('car', 771),
#  ('top', 766),
#  ('water', 739),
#  ('right', 732),
#  ('sure', 730),
#  ('another', 727),
#  ('every', 717),
#  ('find', 710),
#  ('child', 705),
#  ('being', 697),
#  ('able', 696),
#  ('monitor', 686),
#  ('different', 685),
#  ('actually', 683),
#  ('through', 683),
#  ('try', 681),
#  ('3', 681),
#  ('found', 679),
#  ('same', 675),
#  ("I've", 669),
#  ('lot', 665),
#  ('size', 657),
#  ('makes', 656),
#  ('stroller', 654),
#  ('wanted', 651),
#  ('side', 646),
#  ('without', 646),
#  ('getting', 631),
#  ('seems', 626),
#  ('quality', 626),
#  ('long', 622),
#  ('nice', 615),
#  ('should', 609),
#  ('cover', 599),
#  ('purchased', 597),
#  ("wouldn't", 595),
#  ('many', 588),
#  ('where', 574),
#  ('looking', 572),
#  ('bit', 567),
#  ('pump', 560),
#  ('them.', 555),
#  ("isn't", 554),
#  ('However,', 552),
#  ('part', 545),
#  ('started', 544),
#  ('toy', 538),
#  ('trying', 536),
#  ('reviews', 528),
#  ('feel', 525),
#  ("baby's", 524),
#  ('having', 522),
#  ('bottom', 520),
#  ('&', 515),
#  ('worth', 515),
#  ('gets', 514),
#  ('always', 513),
#  ('ended', 512),
#  ("wasn't", 511),
#  ('milk', 510),
#  ('less', 504),
#  ('money', 501),
#  ('once', 500),
#  ('easily', 499),
#  ('both', 497),
#  ('4', 497),
#  ('looks', 494),
#  ('works', 489),
#  ("won't", 487),
#  ('food', 484),
#  ('head', 482),
#  ('seem', 481),
#  ('out.', 475),
#  ('times', 475),
#  ('stay', 472),
#  ('might', 469),
#  ('difficult', 469),
#  ('crib', 465),
#  ('open', 459),
#  ('cute', 458),
#  ('soft', 457),
#  ('things', 457),
#  ('5', 452),
#  ('problem', 451),
#  ('until', 451),
#  ('design', 446),
#  ('may', 442),
#  ('clean', 441),
#  ("I'd", 441),
#  ('set', 437),
#  ('high', 433),
#  ('wash', 432),
#  ('almost', 428),
#  ('worked', 428),
#  ('price', 427),
#  ('swing', 425),
#  ('diapers', 424),
#  ('far', 423),
#  ('idea', 421),
#  ('Also,', 420),
#  ('wish', 420),
#  ('already', 419),
#  ('took', 418),
#  ('baby.', 418),
#  ('room', 415),
#  ('fabric', 413),
#  ('night', 411),
#  ('all.', 411),
#  ('came', 411),
#  ('last', 406),
#  ('went', 406),
#  ('chair', 405),
#  ('under', 404),
#  ('6', 401),
#  ("you're", 399),
#  ('probably', 399),
#  ('those', 399),
#  ('disappointed', 398),
#  ('quite', 397),
#  ('several', 397),
#  ('gate', 397),
#  ('liked', 396),
#  ('buying', 394),
#  ('though', 393),
#  ('couple', 392),
#  ('return', 392),
#  ('loved', 391),
#  ('second', 390),
#  ('comes', 390),
#  ('end', 389),
#  ('turn', 389),
#  ('item', 387),
#  ("couldn't", 386),
#  ('anything', 385),
#  ('pull', 384),
#  ('toys', 383),
#  ('nipple', 383),
#  ('play', 381),
#  ('material', 380),
#  ('sleep', 379),
#  ('each', 377),
#  ('between', 376),
#  ('babies', 373),
#  ('inside', 373),
#  ('one.', 370),
#  ('Baby', 370),
#  ('seemed', 370),
#  ('regular', 369),
#  ('away', 369),
#  ('why', 368),
#  ('sound', 368),
#  ('gave', 365),
#  ('use.', 364),
#  ("that's", 359),
#  ('straps', 357),
#  ('cups', 357),
#  ('whole', 356),
#  ('light', 355),
#  ('well.', 353),
#  ('help', 352),
#  ('stars', 351),
#  ('place', 350),
#  ('again.', 349),
#  ('pillow', 348),
#  ('suction', 347),
#  ('extra', 344),
#  ('kind', 344),
#  ('maybe', 344),
#  ('ordered', 342),
#  ('lid', 340),
#  ('me.', 340),
#  ('ones', 339),
#  ('returned', 339),
#  ('definitely', 339),
#  ('front', 337),
#  ('large', 337),
#  ('time.', 334),
#  ('making', 334),
#  ('cloth', 334),
#  ('instead', 331),
#  ('decided', 331),
#  ('piece', 330),
#  ('changing', 329),
#  ('received', 329),
#  ('completely', 328),
#  ('this.', 328),
#  ('least', 328),
#  ('weeks', 327),
#  ('bad', 326),
#  ('hand', 320),
#  ('husband', 319),
#  ('tub', 319),
#  ('sit', 319),
#  ('toddler', 318),
#  ('product.', 318),
#  ('pad', 317),
#  ('super', 316),
#  ('stick', 315),
#  ('off.', 312),
#  ('sippy', 312),
#  ('1', 311),
#  ('cannot', 310),
#  ('waste', 309),
#  ('leak', 309),
#  ('cheap', 308),
#  ('up.', 307),
#  ('longer', 307),
#  ('comfortable', 306),
#  ('looked', 306),
#  ('kids', 304),
#  ('close', 303),
#  ('takes', 297),
#  ('again', 297),
#  ('older', 295),
#  ('minutes', 293),
#  ('better.', 293),
#  ('mattress', 292),
#  ('three', 292),
#  ('nothing', 291),
#  ('best', 291),
#  ('own', 289),
#  ('easier', 287),
#  ('putting', 287),
#  ('rather', 285),
#  ('bags', 282),
#  ('needed', 281),
#  ('read', 281),
#  ('move', 281),
#  ('expensive', 279),
#  ('smaller', 277),
#  ('supposed', 276),
#  ('fall', 276),
#  ('Maybe', 275),
#  ('kept', 275),
#  ('legs', 275),
#  ('wipes', 274),
#  ('seat.', 274),
#  ('tray', 274),
#  ('let', 273),
#  ('order', 272),
#  ('stopped', 272),
#  ('such', 272),
#  ('brand', 272),
#  ('thin', 271),
#  ('infant', 271),
#  ('on.', 270),
#  ('fine', 270),
#  ('loves', 269),
#  ('everything', 268),
#  ('purchase', 267),
#  ('half', 267),
#  ('hands', 266),
#  ('strap', 266),
#  ('reason', 264),
#  ('goes', 264),
#  ('next', 262),
#  ('parts', 262),
#  ('said', 262),
#  ('smell', 261),
#  ('together', 260),
#  ('especially', 259),
#  ('tight', 257),
#  ('10', 257),
#  ('camera', 255),
#  ('guess', 253),
#  ('hear', 252),
#  ('short', 250),
#  ('onto', 250),
#  ('during', 249),
#  ('store', 248),
#  ('needs', 247),
#  ('handle', 247),
#  ('issue', 246),
#  ('carrier', 246),
#  ('velcro', 244),
#  ('unit', 243),
#  ('either', 243),
#  ('us.', 243),
#  ('support', 241),
#  ('brush', 241),
#  ('happy', 238),
#  ('pain', 238),
#  ('newborn', 238),
#  ('change', 237),
#  ('stuck', 236),
#  ('weight', 236),
#  ('fact', 235),
#  ('color', 235),
#  ('people', 234),
#  ('straw', 234),
#  ('work.', 233),
#  ('heavy', 231),
#  ('music', 229),
#  ('potty', 229),
#  ('point', 228),
#  ('air', 228),
#  ('months.', 228),
#  ('8', 227),
#  ('fits', 227),
#  ('unless', 227),
#  ('pack', 227),
#  ('table', 227),
#  ("I'll", 225),
#  ('sitting', 225),
#  ('huge', 224),
#  ('money.', 223),
#  ('Amazon', 222),
#  ('likes', 222),
#  ('pieces', 222),
#  ('working', 222),
#  ('picture', 221),
#  ('(which', 221),
#  ('noise', 220),
#  ('returning', 218),
#  ('all,', 218),
#  ('kid', 217),
#  ('push', 217),
#  ('left', 216),
#  ('constantly', 216),
#  ('remove', 216),
#  ('barely', 215),
#  ('middle', 214),
#  ('excited', 214),
#  ('Very', 214),
#  ('full', 213),
#  ('noticed', 213),
#  ('washed', 213),
#  ('impossible', 213),
#  ('broke', 212),
#  ('review', 212),
#  ('within', 212),
#  ('itself', 212),
#  ("they're", 212),
#  ('nipples', 211),
#  ('them,', 210),
#  ('box', 210),
#  ('felt', 210),
#  ('week', 209),
#  ('days', 209),
#  ('Medela', 209),
#  ('hoping', 208),
#  ('apart', 207),
#  ('against', 207),
#  ('ever', 206),
#  ('must', 206),
#  ('bath', 206),
#  ('white', 206),
#  ('space', 205),
#  ('feet', 205),
#  ('prefer', 205),
#  ('great.', 204),
#  ('video', 204),
#  ('mouth', 201),
#  ('out,', 201),
#  ('leaks', 201),
#  ('start', 201),
#  ('matter', 201),
#  ('flat', 201),
#  ('mirror', 201),
#  ('back.', 200),
#  ('breast', 200),
#  ('battery', 199),
#  ('low', 199),
#  ('thinking', 199),
#  ('(and', 199),
#  ('base', 199),
#  ('baby,', 198),
#  ('replace', 197),
#  ("aren't", 197),
#  ('sides', 197),
#  ('cut', 197),
#  ("haven't", 196),
#  ('well,', 196),
#  ('on,', 195),
#  ('due', 194),
#  ('perfect', 194),
#  ('home', 194),
#  ('sometimes', 194),
#  ('poor', 192),
#  ('these.', 191),
#  ('bed', 191),
#  ('one,', 191),
#  ('warm', 191),
#  ('time,', 190),
#  ('covers', 190),
#  ('holding', 190),
#  ('this,', 190),
#  ('bag.', 190),
#  ('sheet', 189),
#  ('washing', 189),
#  ('larger', 188),
#  ('old.', 188),
#  ('means', 188),
#  ('hot', 188),
#  ('else', 188),
#  ('dry', 187),
#  ('entire', 187),
#  ('--', 187),
#  ('shape', 187),
#  ('figure', 186),
#  ('(I', 186),
#  ('finally', 185),
#  ('in.', 185),
#  ('feature', 185),
#  ("there's", 183),
#  ('bottles.', 183),
#  ('customer', 183),
#  ('turned', 181),
#  ('products', 180),
#  ('months,', 180),
#  ('feels', 180),
#  ('pay', 180),
#  ('insert', 180),
#  ('attached', 179),
#  ('free', 179),
#  ('use,', 179),
#  ('others', 179),
#  ('liquid', 179),
#  ('button', 179),
#  ('there.', 178),
#  ('stand', 178),
#  ('wide', 178),
#  ('years', 177),
#  ('quickly', 177),
#  ('opening', 177),
#  ('hate', 177),
#  ('that.', 177),
#  ('given', 177),
#  ('sleeping', 177),
#  ('door', 176),
#  ('bigger', 176),
#  ('house', 176),
#  ('doing', 176),
#  ('replacement', 176),
#  ('seat,', 176),
#  ('neck', 176),
#  ('reach', 175),
#  ('wear', 175),
#  ("son's", 174),
#  ('attach', 174),
#  ('Unfortunately,', 174),
#  ('extremely', 174),
#  ('blanket', 174),
#  ('simply', 173),
#  ('pads', 173),
#  ('case', 173),
#  ('coming', 173),
#  ('holes', 172),
#  ('travel', 172),
#  ('spout', 172),
#  ('forward', 171),
#  ('says', 171),
#  ('uncomfortable', 170),
#  ('throw', 170),
#  ('up,', 169),
#  ('falls', 169),
#  ('amount', 168),
#  ('thick', 168),
#  ('bib', 168),
#  ('Avent', 168),
#  ('So,', 167),
#  ('me,', 167),
#  ('pocket', 167),
#  ('however', 166),
#  ('carry', 166),
#  ('fold', 166),
#  ('safe', 166),
#  ('parent', 166),
#  ('tell', 165),
#  ('too.', 165),
#  ('colors', 165),
#  ('While', 165),
#  ('cold', 165),
#  ('rubber', 165),
#  ('mat', 165),
#  ('leave', 164),
#  ('spend', 164),
#  ('figured', 164),
#  ('problems', 163),
#  ('holds', 163),
#  ('sounds', 163),
#  ("he's", 163),
#  ('drink', 163),
#  ('rest', 162),
#  ('care', 162),
#  ('often', 162),
#  ('real', 161),
#  ('usually', 161),
#  ('snap', 160),
#  ('cheaper', 160),
#  ('standard', 158),
#  ('soon', 158),
#  ('designed', 158),
#  ('absolutely', 157),
#  ('yet', 157),
#  ('deal', 157),
#  ('useful', 157),
#  ('annoying', 156),
#  ('zipper', 156),
#  ('giving', 156),
#  ('warmer', 156),
#  ('adjust', 156),
#  ('safety', 156),
#  ('however,', 155),
#  ('loud', 155),
#  ('strong', 155),
#  ('sent', 155),
#  ('issues', 154),
#  ('face', 154),
#  ('nearly', 153),
#  ('position', 153),
#  ('myself', 152),
#  ('along', 152),
#  ('wipe', 151),
#  ('down.', 151),
#  ('bulky', 151),
#  ('fell', 151),
#  ('that,', 151),
#  ('again,', 151),
#  ('save', 150),
#  ('pacifier', 150),
#  ('stuff', 150),
#  ('blue', 150),
#  ('7', 149),
#  ('batteries', 149),
#  ('wet', 149),
#  ('falling', 149),
#  ('hang', 149),
#  ('option', 149),
#  ('based', 148),
#  ('arms', 148),
#  ('hole', 147),
#  ('now.', 147),
#  ('expect', 147),
#  ('concept', 147),
#  ('loose', 146),
#  ('flimsy', 146),
#  ('expected', 145),
#  ('saw', 145),
#  ('stroller.', 145),
#  ('realized', 144),
#  ('floor', 144),
#  ('here', 143),
#  ('shower', 143),
#  ('done', 143),
#  ('flow', 143),
#  ('similar', 143),
#  ('system', 143),
#  ('though.', 143),
#  ('main', 143),
#  ('lock', 143),
#  ('great,', 142),
#  ('tiny', 142),
#  ('outside', 142),
#  ('clear', 141),
#  ('useless', 141),
#  ('job', 141),
#  ('taking', 141),
#  ('mobile', 141),
#  ('company', 140),
#  ('someone', 140),
#  ('type', 140),
#  ('bottle.', 140),
#  ('service', 140),
#  ('motor', 140),
#  ('keeps', 140),
#  ('quality.', 140),
#  ('facing', 140),
#  ('mine', 139),
#  ('either.', 139),
#  ('keeping', 139),
#  ('instructions', 139),
#  ('cost', 139),
#  ('Britax', 139),
#  ('secure', 138),
#  ('nursing', 138),
#  ('carseat', 138),
#  ('Graco', 138),
#  ('him.', 136),
#  ('basically', 136),
#  ('slightly', 136),
#  ('cause', 136),
#  ('price.', 136),
#  ('run', 136),
#  ('although', 136),
#  ('etc.', 136),
#  ('cute,', 136),
#  ('star', 135),
#  ('in,', 135),
#  ('fun', 135),
#  ('line', 134),
#  ('product,', 134),
#  ('purpose', 134),
#  ('wrong', 134),
#  ('place.', 134),
#  ('9', 134),
#  ('off,', 133),
#  ('stop', 133),
#  ('sits', 133),
#  ('send', 133),
#  ('reading', 132),
#  ("we've", 131),
#  ('fast', 131),
#  ('four', 131),
#  ('bar', 131),
#  ("she's", 131),
#  ('seats', 130),
#  ('latch', 130),
#  ('spoon', 130),
#  ('simple', 129),
#  ('gotten', 129),
#  ('believe', 129),
#  ('area', 129),
#  ('much.', 129),
#  ('volume', 129),
#  ('cleaning', 129),
#  ('instead.', 128),
#  ('small.', 128),
#  ('20', 128),
#  ('items', 128),
#  ('ends', 128),
#  ('Once', 128),
#  ('wrap', 128),
#  ("Don't", 127),
#  ('near', 127),
#  ('version', 127),
#  ('imagine', 127),
#  ('(the', 126),
#  ('said,', 126),
#  ('bowl', 126),
#  ('easily.', 126),
#  ('swaddle', 126),
#  ('dirty', 125),
#  ('bag,', 125),
#  ('idea,', 125),
#  ('wall', 125),
#  ('children', 125),
#  ('later', 125),
#  ('break', 125),
#  ('actual', 124),
#  ('sturdy', 124),
#  ('room.', 124),
#  ('storage', 124),
#  ('fairly', 124),
#  ('feeding', 124),
#  ('purchasing', 124),
#  ('live', 124),
#  ('Since', 123),
#  ('awkward', 123),
#  ('held', 123),
#  ('touch', 123),
#  ('single', 123),
#  ('disappointed.', 123),
#  ('double', 123),
#  ('clip', 123),
#  ('understand', 123),
#  ('foam', 123),
#  ('chew', 122),
#  ('positive', 122),
#  ('slide', 122),
#  ('ring', 122),
#  ('straight', 122),
#  ('Dr.', 122),
#  ('pumping', 122),
#  ('body', 122),
#  ('though,', 122),
#  ('allow', 121),
#  ('crib.', 121),
#  ('sheets', 121),
#  ('inches', 121),
#  ('her.', 121),
#  ('bibs', 121),
#  ('cup.', 120),
#  ('clean.', 120),
#  ('hours', 120),
#  ('setting', 120),
#  ('original', 120),
#  ('angle', 119),
#  ('hope', 119),
#  ('hit', 119),
#  ('uses', 119),
#  ('description', 119),
#  ('holder', 119),
#  ('properly', 118),
#  ('lay', 118),
#  ('model', 118),
#  ('metal', 118),
#  ('compared', 118),
#  ('roll', 118),
#  ('suck', 117),
#  ('foot', 117),
#  ('add', 117),
#  ('pick', 117),
#  ('elastic', 116),
#  ('totally', 116),
#  ('mind', 116),
#  ('toilet', 116),
#  ('bottles,', 116),
#  ('machine', 116),
#  ('ok', 115),
#  ('toy.', 115),
#  ('trouble', 115),
#  ('reviewers', 115),
#  ('sort', 115),
#  ('rear', 115),
#  ('leaking', 114),
#  ('screw', 114),
#  ('became', 114),
#  ('born', 114),
#  ('away.', 114),
#  ('gift', 114),
#  ('fan', 114),
#  ('it!', 113),
#  ('mom', 113),
#  ('switch', 113),
#  ('handles', 113),
#  ('child.', 113),
#  ('silicone', 113),
#  ('called', 113),
#  ('stays', 112),
#  ('pulled', 112),
#  ('wearing', 112),
#  ('cotton', 112),
#  ('frame', 111),
#  ('now,', 111),
#  ('check', 111),
#  ('spent', 111),
#  ('biggest', 111),
#  ('snaps', 110),
#  ('dont', 110),
#  ('pop', 110),
#  ('hated', 110),
#  ('suggest', 110),
#  ('told', 110),
#  ('VERY', 110),
#  ('pail', 109),
#  ('plus', 109),
#  ('red', 109),
#  ('enough.', 109),
#  ('arrived', 108),
#  ('fill', 108),
#  ('power', 108),
#  ('not.', 108),
#  ('twice', 108),
#  ("you'll", 108),
#  ('with.', 108),
#  ('fully', 108),
#  ('Too', 108),
#  ('installed', 108),
#  ('past', 108),
#  ('normal', 107),
#  ('starting', 107),
#  ('reviews.', 107),
#  ('30', 107),
#  ('price,', 107),
#  ('is,', 106),
#  ('opened', 106),
#  ('major', 106),
#  ('prevent', 106),
#  ('fine.', 106),
#  ('paid', 106),
#  ('realize', 105),
#  ('pee', 105),
#  ('clothes', 105),
#  ('Fisher', 105),
#  ('However', 105),
#  ('shoulder', 105),
#  ('dishwasher', 105),
#  ('edge', 104),
#  ('hanging', 104),
#  ('leak.', 104),
#  ('lost', 104),
#  ('useless.', 104),
#  ('pressure', 104),
#  ('wheels', 104),
#  ('thing.', 103),
#  ("we're", 103),
#  ('parents', 103),
#  ("daughter's", 103),
#  ('soft,', 103),
#  ('experience', 103),
#  ('15', 103),
#  ('lift', 102),
#  ('old,', 102),
#  ('first,', 102),
#  ('recommended', 102),
#  ('leaked', 102),
#  ('screen', 102),
#  ('anyone', 101),
#  ('starts', 101),
#  ('mess', 101),
#  ('turns', 101),
#  ('night.', 101),
#  ('mouth.', 101),
#  ('highly', 101),
#  ('tall', 101),
#  ('Bjorn', 101),
#  ('bright', 101),
#  ('seen', 101),
#  ('anymore.', 100),
#  ('for.', 100),
#  ('install', 100),
#  ('fine,', 100),
#  ('together.', 100),
#  ('higher', 100),
#  ('plan', 100),
#  ('window', 100),
#  ('glass', 100),
#  ('Summer', 100),
#  ('decent', 100),
#  ('green', 100),
#  ('Well,', 99),
#  ('hopes', 99),
#  ('avoid', 99),
#  ('cap', 99),
#  ('Price', 99),
#  ('level', 99),
#  ('lights', 99),
#  ('lots', 98),
#  ('more.', 98),
#  ('1/2', 98),
#  ('options', 98),
#  ('way.', 98),
#  ('perfectly', 98),
#  ('temperature', 97),
#  ('to.', 97),
#  ('age', 97),
#  ('you.', 97),
#  ('monitor.', 97),
#  ('Unfortunately', 97),
#  ('package', 96),
#  ('cool', 96),
#  ('side,', 96),
#  ('life', 96),
#  ('leg', 96),
#  ('moving', 96),
#  ('edges', 96),
#  ('is.', 96),
#  ('burp', 96),
#  ('formula', 96),
#  ('pump.', 96),
#  ('good.', 96),
#  ('problem.', 96),
#  ('bassinet', 96),
#  ('sun', 96),
#  ('blankets', 96),
#  ('heard', 95),
#  ('around.', 95),
#  ('liner', 95),
#  ('reviews,', 95),
#  ('mesh', 95),
#  ('lids', 95),
#  ('exactly', 94),
#  ('interested', 94),
#  ('height', 94),
#  ('these,', 94),
#  ('feed', 94),
#  ('container', 94),
#  ('likely', 94),
#  ('behind', 94),
#  ('switched', 94),
#  ('twins', 94),
#  ('side.', 94),
#  ('overall', 94),
#  ("That's", 94),
#  ('wants', 93),
#  ('whether', 93),
#  ("child's", 93),
#  ('plastic.', 93),
#  ('harder', 93),
#  ('brands', 93),
#  ('hour', 93),
#  ('wood', 93),
#  ('friend', 93),
#  ('day.', 92),
#  ('broken', 92),
#  ('pulling', 92),
#  ('small,', 92),
#  ('sling', 92),
#  ('lower', 92),
#  ('leaving', 92),
#  ('boy', 92),
#  ('item.', 92),
#  ('multiple', 92),
#  ('arm', 92),
#  ('lbs', 92),
#  ('covered', 92),
#  ('diapers.', 91),
#  ('gone', 91),
#  ('show', 91),
#  ('bother', 91),
#  ('sized', 91),
#  ('length', 91),
#  ('work,', 91),
#  ('features', 91),
#  ('mechanism', 90),
#  ('tape', 90),
#  ("We've", 90),
#  ('long.', 90),
#  ('terrible', 90),
#  ('immediately', 90),
#  ('surface', 90),
#  ('favorite', 90),
#  ('cup,', 90),
#  ('down,', 90),
#  ('teething', 89),
#  ('helpful', 89),
#  ('knew', 89),
#  ('step', 89),
#  ('Munchkin', 89),
#  ('else.', 89),
#  ('become', 89),
#  ('difference', 89),
#  ('poorly', 89),
#  ('literally', 89),
#  ('carrying', 89),
#  ('Ergo', 89),
#  ('trash', 88),
#  ('hassle', 88),
#  ('hurt', 88),
#  ('otherwise', 88),
#  ('heat', 88),
#  ('wait', 88),
#  ('screws', 88),
#  ('walk', 88),
#  ...]

# %%
three_text
# Out:
# [('', 32454),
#  ('is', 32018),
#  ('was', 12549),
#  ('are', 11762),
#  ('baby', 7754),
#  ('very', 6092),
#  ('had', 5427),
#  ('really', 5426),
#  ('more', 5127),
#  ('has', 4710),
#  ('little', 4551),
#  ("don't", 4387),
#  ('it.', 4096),
#  ('too', 4029),
#  ('much', 3832),
#  ('seat', 3451),
#  ("doesn't", 3363),
#  ('put', 3124),
#  ('still', 3122),
#  ('does', 3120),
#  ('-', 3093),
#  ('son', 2991),
#  ('great', 2972),
#  ("I'm", 2819),
#  ('were', 2718),
#  ('used', 2655),
#  ("didn't", 2634),
#  ('bought', 2632),
#  ('using', 2631),
#  ('off', 2540),
#  ('old', 2445),
#  ('fit', 2402),
#  ('better', 2380),
#  ('easy', 2324),
#  ('got', 2307),
#  ('months', 2284),
#  ('keep', 2126),
#  ('daughter', 2111),
#  ('am', 2089),
#  ('around', 2046),
#  ('enough', 2013),
#  ('been', 2004),
#  ('product', 1998),
#  ('hard', 1971),
#  ('small', 1942),
#  ('few', 1933),
#  ('nice', 1916),
#  ('love', 1912),
#  ('need', 1898),
#  ('bit', 1896),
#  ('diaper', 1883),
#  ('did', 1867),
#  ('it,', 1860),
#  ('since', 1843),
#  ('while', 1808),
#  ('pretty', 1802),
#  ('car', 1796),
#  ('bag', 1771),
#  ("can't", 1757),
#  ('down', 1734),
#  ('stroller', 1734),
#  ('3', 1707),
#  ('made', 1686),
#  ('sure', 1683),
#  ('something', 1682),
#  ('seems', 1680),
#  ('2', 1668),
#  ('big', 1632),
#  ('buy', 1611),
#  ('bottle', 1574),
#  ('hold', 1556),
#  ('month', 1548),
#  ('lot', 1536),
#  ('find', 1526),
#  ('able', 1506),
#  ('thought', 1484),
#  ('size', 1471),
#  ('thing', 1441),
#  ('going', 1421),
#  ('bottles', 1411),
#  ('However,', 1400),
#  ('side', 1381),
#  ('being', 1367),
#  ('child', 1360),
#  ('before', 1354),
#  ("isn't", 1352),
#  ('without', 1336),
#  ('right', 1327),
#  ('cup', 1326),
#  ('plastic', 1322),
#  ('works', 1311),
#  ('different', 1302),
#  ('tried', 1301),
#  ('top', 1301),
#  ('never', 1299),
#  ("I've", 1292),
#  ('cover', 1286),
#  ('wish', 1278),
#  ('another', 1260),
#  ('long', 1257),
#  ('water', 1249),
#  ('toy', 1234),
#  ('gets', 1230),
#  ('through', 1211),
#  ('makes', 1210),
#  ('same', 1192),
#  ('getting', 1189),
#  ('found', 1180),
#  ('every', 1176),
#  ('seem', 1165),
#  ('try', 1132),
#  ('feel', 1127),
#  ('having', 1107),
#  ('where', 1106),
#  ('easily', 1090),
#  ('probably', 1090),
#  ('should', 1063),
#  ('actually', 1059),
#  ('once', 1057),
#  ('price', 1057),
#  ('soft', 1056),
#  ('quite', 1054),
#  ('quality', 1038),
#  ('many', 1033),
#  ('may', 1024),
#  ('looking', 1021),
#  ('both', 1019),
#  ('things', 1014),
#  ('recommend', 1014),
#  ('play', 1013),
#  ('wanted', 1011),
#  ('part', 1006),
#  ('bottom', 1005),
#  ('purchased', 1003),
#  ('problem', 991),
#  ('though', 991),
#  ('always', 979),
#  ('might', 975),
#  ('5', 972),
#  ('4', 971),
#  ('crib', 961),
#  ('clean', 952),
#  ('less', 950),
#  ('high', 949),
#  ('cute', 942),
#  ("wouldn't", 939),
#  ('them.', 933),
#  ('toys', 927),
#  ('set', 927),
#  ("baby's", 924),
#  ('food', 924),
#  ('difficult', 920),
#  ("I'd", 917),
#  ('room', 912),
#  ('pump', 912),
#  ('head', 903),
#  ('those', 899),
#  ("wasn't", 895),
#  ('looks', 892),
#  ('well.', 883),
#  ('open', 879),
#  ('monitor', 873),
#  ('chair', 868),
#  ('started', 864),
#  ('trying', 862),
#  ('Also,', 861),
#  ('almost', 859),
#  ('milk', 855),
#  ('out.', 854),
#  ('wash', 853),
#  ('fabric', 850),
#  ('until', 835),
#  ('&', 829),
#  ('definitely', 829),
#  ("won't", 826),
#  ('comes', 822),
#  ('under', 815),
#  ("you're", 803),
#  ('extra', 803),
#  ('far', 797),
#  ('pull', 795),
#  ('ones', 789),
#  ('times', 786),
#  ('stay', 781),
#  ('light', 781),
#  ('straps', 777),
#  ('large', 776),
#  ('last', 767),
#  ('loves', 764),
#  ('sleep', 761),
#  ('6', 761),
#  ('design', 760),
#  ('kind', 755),
#  ('anything', 753),
#  ('came', 745),
#  ('comfortable', 744),
#  ('babies', 743),
#  ('worth', 741),
#  ('material', 737),
#  ('easier', 736),
#  ("that's", 736),
#  ('pillow', 735),
#  ('diapers', 734),
#  ('place', 729),
#  ('smaller', 729),
#  ('end', 729),
#  ('couple', 724),
#  ('worked', 723),
#  ('liked', 721),
#  ('ended', 716),
#  ('front', 716),
#  ('stars', 714),
#  ('likes', 713),
#  ('fits', 712),
#  ('baby.', 710),
#  ('each', 703),
#  ('best', 701),
#  ('move', 701),
#  ('time.', 701),
#  ('between', 699),
#  ('sit', 696),
#  ('Baby', 695),
#  ('reviews', 695),
#  ('tray', 687),
#  ('hand', 678),
#  ('cloth', 677),
#  ('took', 674),
#  ('turn', 671),
#  ('kids', 668),
#  ('inside', 661),
#  ('why', 660),
#  ('longer', 660),
#  ('maybe', 655),
#  ('infant', 652),
#  ('three', 652),
#  ('one.', 650),
#  ('changing', 649),
#  ('nipple', 646),
#  ('toddler', 643),
#  ('help', 642),
#  ('cups', 642),
#  ('away', 640),
#  ('older', 639),
#  ('super', 634),
#  ('already', 631),
#  ('idea', 629),
#  ('fine', 626),
#  ('second', 621),
#  ('least', 615),
#  ('seemed', 615),
#  ('several', 614),
#  ('item', 612),
#  ('regular', 610),
#  ('rather', 609),
#  ('needed', 607),
#  ('swing', 606),
#  ('takes', 600),
#  ('night', 599),
#  ('pad', 598),
#  ('instead', 597),
#  ('piece', 595),
#  ('husband', 590),
#  ('sound', 585),
#  ('weight', 585),
#  ('close', 584),
#  ('1', 582),
#  ('wipes', 581),
#  ('me.', 579),
#  ('seat.', 574),
#  ('ordered', 573),
#  ('color', 573),
#  ('again', 572),
#  ('gate', 571),
#  ('bad', 570),
#  ('loved', 569),
#  ('especially', 569),
#  ('whole', 566),
#  ('buying', 565),
#  ('handle', 563),
#  ('tub', 563),
#  ('next', 562),
#  ('putting', 560),
#  ('music', 554),
#  ('guess', 552),
#  ('weeks', 550),
#  ('use.', 550),
#  ("they're", 550),
#  ('strap', 548),
#  ('issue', 548),
#  ('mattress', 545),
#  ('prefer', 545),
#  ("couldn't", 544),
#  ('up.', 541),
#  ('own', 539),
#  ("haven't", 539),
#  ('perfect', 539),
#  ('lid', 538),
#  ('suction', 538),
#  ('purchase', 537),
#  ('gave', 530),
#  ('job', 528),
#  ("aren't", 522),
#  ('during', 521),
#  ('hands', 520),
#  ('making', 518),
#  ("he's", 515),
#  ('needs', 513),
#  ('off.', 511),
#  ('on.', 509),
#  ('sippy', 509),
#  ('stick', 507),
#  ('bags', 507),
#  ('decided', 506),
#  ('short', 506),
#  ('carrier', 506),
#  ('went', 504),
#  ('money', 503),
#  ('everything', 499),
#  ('bigger', 498),
#  ('received', 495),
#  ('velcro', 495),
#  ('reason', 494),
#  ('store', 492),
#  ('fall', 490),
#  ('nothing', 490),
#  ('completely', 487),
#  ('let', 486),
#  ('better.', 486),
#  ('either', 484),
#  ('this.', 483),
#  ('though.', 476),
#  ("I'll", 476),
#  ('legs', 476),
#  ('change', 475),
#  ('larger', 474),
#  ('leak', 474),
#  ('sometimes', 474),
#  ('push', 473),
#  ('base', 472),
#  ('straw', 471),
#  ('Maybe', 470),
#  ('pack', 466),
#  ('great.', 466),
#  ('read', 465),
#  ('fact', 465),
#  ('cannot', 464),
#  ('thin', 462),
#  ('travel', 461),
#  ('heavy', 460),
#  ('minutes', 457),
#  ('covers', 456),
#  ('colors', 454),
#  ('tight', 453),
#  ('happy', 453),
#  ('remove', 453),
#  ('newborn', 451),
#  ('people', 449),
#  ('goes', 449),
#  ('full', 448),
#  ('said', 446),
#  ('cheap', 446),
#  ('order', 445),
#  ('again.', 444),
#  ('sitting', 443),
#  ('brand', 443),
#  ('such', 442),
#  ('product.', 442),
#  ('carry', 441),
#  ('disappointed', 441),
#  ('(I', 440),
#  ('white', 439),
#  ('pieces', 438),
#  ('mirror', 437),
#  ('table', 436),
#  ('expensive', 435),
#  ('old.', 435),
#  ('together', 435),
#  ('space', 434),
#  ('supposed', 434),
#  ('half', 433),
#  ('kid', 433),
#  ('all.', 431),
#  ('nipples', 429),
#  ('point', 426),
#  ('others', 426),
#  ('hoping', 423),
#  ('dry', 422),
#  ('parts', 420),
#  ('them,', 418),
#  ('start', 417),
#  ('10', 413),
#  ('this,', 411),
#  ('itself', 411),
#  ('huge', 409),
#  ('fold', 409),
#  ('mat', 404),
#  ('blanket', 404),
#  ('well,', 402),
#  ('bag.', 401),
#  ('onto', 401),
#  ('pain', 400),
#  ('stuck', 399),
#  ('often', 397),
#  ('though,', 397),
#  ('potty', 396),
#  ('brush', 395),
#  ('seat,', 394),
#  ('(and', 394),
#  ('hot', 394),
#  ('left', 393),
#  ('however,', 390),
#  ('however', 390),
#  ('middle', 389),
#  ("there's", 386),
#  ('sides', 386),
#  ('feature', 386),
#  ('8', 385),
#  ('against', 385),
#  ('leave', 384),
#  ('months.', 383),
#  ('review', 382),
#  ('air', 381),
#  ('battery', 381),
#  ('camera', 381),
#  ('return', 379),
#  ('yet', 379),
#  ('that.', 378),
#  ('baby,', 377),
#  ('wear', 377),
#  ('door', 377),
#  ('flat', 376),
#  ('warm', 375),
#  ('main', 375),
#  ('up,', 374),
#  ('unless', 374),
#  ('support', 373),
#  ('although', 372),
#  ('kept', 372),
#  ('said,', 371),
#  ('holding', 371),
#  ('out,', 370),
#  ('sturdy', 369),
#  ('stroller.', 368),
#  ('washing', 367),
#  ('bath', 367),
#  ('opening', 366),
#  ('holes', 366),
#  ('attached', 363),
#  ('(which', 363),
#  ('keeps', 362),
#  ('seats', 362),
#  ('option', 361),
#  ('time,', 361),
#  ('mouth', 359),
#  ('looked', 359),
#  ('--', 358),
#  ('wide', 358),
#  ('house', 357),
#  ('unit', 357),
#  ('pocket', 357),
#  ('smell', 356),
#  ('annoying', 356),
#  ('breast', 356),
#  ('slightly', 355),
#  ('feels', 355),
#  ('usually', 354),
#  ('feet', 354),
#  ('adjust', 354),
#  ('must', 353),
#  ('that,', 351),
#  ('system', 349),
#  ('reach', 348),
#  ('While', 348),
#  ('holds', 347),
#  ('in.', 347),
#  ('safety', 347),
#  ('care', 344),
#  ('washed', 344),
#  ("she's", 343),
#  ('type', 342),
#  ('means', 342),
#  ('due', 341),
#  ('box', 341),
#  ('fairly', 341),
#  ('noise', 341),
#  ('forward', 340),
#  ('use,', 339),
#  ('button', 338),
#  ('deal', 337),
#  ('case', 337),
#  ('taking', 336),
#  ('figure', 336),
#  ('storage', 336),
#  ('picture', 335),
#  ('keeping', 334),
#  ('me,', 334),
#  ('amount', 334),
#  ('insert', 334),
#  ('mobile', 333),
#  ('Britax', 333),
#  ('hang', 332),
#  ('snap', 332),
#  ('months,', 332),
#  ('So,', 331),
#  ('issues', 330),
#  ('position', 329),
#  ('attach', 328),
#  ('shape', 328),
#  ('else', 328),
#  ('all,', 326),
#  ('thick', 325),
#  ('work.', 325),
#  ('these.', 324),
#  ('stuff', 324),
#  ('bed', 324),
#  ('easily.', 323),
#  ('7', 322),
#  ('stand', 322),
#  ('felt', 322),
#  ('face', 322),
#  ('problems', 321),
#  ('years', 321),
#  ('replace', 321),
#  ('great,', 320),
#  ('home', 320),
#  ('clean.', 319),
#  ('days', 317),
#  ('week', 317),
#  ('there.', 317),
#  ('done', 317),
#  ('quickly', 317),
#  ('useful', 315),
#  ('price.', 315),
#  ('products', 315),
#  ('low', 315),
#  ('ok', 314),
#  ('excited', 313),
#  ('arms', 313),
#  ('sleeping', 312),
#  ('cheaper', 312),
#  ('doing', 312),
#  ('real', 312),
#  ('now.', 310),
#  ('fun', 310),
#  ('expect', 310),
#  ('barely', 309),
#  ('again,', 308),
#  ('facing', 307),
#  ('cute,', 306),
#  ('product,', 306),
#  ('cut', 306),
#  ('bottles.', 306),
#  ('on,', 305),
#  ('bulky', 305),
#  ('him.', 305),
#  ('secure', 305),
#  ('floor', 304),
#  ('one,', 304),
#  ('safe', 304),
#  ('much.', 303),
#  ('mind', 303),
#  ('Medela', 303),
#  ('tell', 302),
#  ('apart', 302),
#  ('pacifier', 300),
#  ('free', 299),
#  ('bar', 299),
#  ('says', 298),
#  ('noticed', 298),
#  ('sheet', 297),
#  ('wet', 297),
#  ('batteries', 297),
#  ('height', 297),
#  ('carseat', 297),
#  ('ever', 296),
#  ('entire', 296),
#  ('run', 296),
#  ('Graco', 296),
#  ('9', 295),
#  ('matter', 294),
#  ('simple', 293),
#  ('purpose', 293),
#  ('old,', 293),
#  ('chew', 293),
#  ('items', 292),
#  ('Avent', 292),
#  ('add', 291),
#  ('working', 291),
#  ('us.', 290),
#  ('wipe', 289),
#  ('interested', 288),
#  ('neck', 288),
#  ('simply', 288),
#  ('back.', 288),
#  ('clip', 288),
#  ('area', 287),
#  ('pay', 287),
#  ('decent', 286),
#  ('pads', 285),
#  ('video', 284),
#  ('nursing', 284),
#  ('drink', 284),
#  ('fine.', 283),
#  ('Amazon', 283),
#  ('etc.', 283),
#  ("son's", 282),
#  ('wheels', 282),
#  ('expected', 281),
#  ('now,', 281),
#  ('throw', 280),
#  ('too.', 280),
#  ('basket', 280),
#  ('similar', 279),
#  ('hear', 279),
#  ('lock', 279),
#  ('compared', 279),
#  ('cotton', 279),
#  ('handles', 278),
#  ('standard', 277),
#  ('turned', 277),
#  ('hit', 275),
#  ('complaint', 275),
#  ('constantly', 275),
#  ('flow', 275),
#  ('reviewers', 274),
#  ('falls', 273),
#  ('rubber', 273),
#  ('given', 273),
#  ('Very', 273),
#  ('stroller,', 273),
#  ('here', 272),
#  ('myself', 272),
#  ('double', 271),
#  ('instructions', 270),
#  ('wrap', 270),
#  ('designed', 270),
#  ('playing', 269),
#  ('replacement', 269),
#  ('install', 269),
#  ('figured', 269),
#  ('coming', 268),
#  ('strong', 268),
#  ('someone', 268),
#  ('four', 268),
#  ('thinking', 267),
#  ('rest', 265),
#  ('sort', 264),
#  ('okay', 264),
#  ('feeding', 264),
#  ('allow', 264),
#  ('zipper', 264),
#  ('price,', 263),
#  ('uses', 261),
#  ('giving', 260),
#  ('down.', 260),
#  ('fast', 260),
#  ('warmer', 260),
#  ('cold', 260),
#  ('latch', 260),
#  ("we've", 259),
#  ('spend', 259),
#  ('pockets', 259),
#  ('along', 258),
#  ('harder', 258),
#  ('exactly', 258),
#  ('cleaning', 258),
#  ('her.', 257),
#  ('stopped', 257),
#  ('gotten', 257),
#  ('tiny', 257),
#  ('pick', 256),
#  ('cost', 256),
#  ('Once', 256),
#  ('outside', 256),
#  ('tall', 255),
#  ('prevent', 254),
#  ('finally', 254),
#  ('extremely', 254),
#  ('impossible', 254),
#  ('plus', 254),
#  ('within', 253),
#  ('loud', 253),
#  ('bottles,', 253),
#  ('hours', 252),
#  ('hole', 252),
#  ('toy.', 251),
#  ('belt', 251),
#  ('plan', 250),
#  ('Since', 249),
#  ('liquid', 249),
#  ('perfectly', 248),
#  ('roll', 248),
#  ('snaps', 247),
#  ('lower', 247),
#  ('Unfortunately,', 247),
#  ('off,', 247),
#  ('held', 246),
#  ('formula', 246),
#  ('feed', 246),
#  ('break', 246),
#  ('hate', 245),
#  ('leaks', 245),
#  ('around.', 244),
#  ('bag,', 243),
#  ('version', 243),
#  ('features', 242),
#  ('(the', 241),
#  ('blue', 240),
#  ('small.', 240),
#  ('nearly', 239),
#  ('company', 239),
#  ('biggest', 238),
#  ('live', 238),
#  ('line', 238),
#  ('multiple', 237),
#  ('overall', 237),
#  ('nice,', 237),
#  ('mine', 237),
#  ('good.', 237),
#  ('falling', 237),
#  ('swaddle', 237),
#  ('imagine', 236),
#  ('sounds', 235),
#  ('sits', 235),
#  ('parent', 235),
#  ('wearing', 234),
#  ('check', 233),
#  ('Overall,', 232),
#  ('shoulder', 232),
#  ('more.', 232),
#  ('rear', 232),
#  ('place.', 232),
#  ('returned', 232),
#  ('slide', 232),
#  ('soon', 231),
#  ('saw', 231),
#  ('spout', 231),
#  ('fine,', 230),
#  ('lots', 229),
#  ('based', 229),
#  ('enjoy', 229),
#  ('crib.', 228),
#  ('save', 227),
#  ('hanging', 227),
#  ('concept', 227),
#  ('ring', 227),
#  ('higher', 226),
#  ('foam', 226),
#  ('side,', 225),
#  ('hope', 225),
#  ('children', 225),
#  ('bright', 225),
#  ('totally', 224),
#  ('side.', 224),
#  ('convenient', 224),
#  ('spoon', 224),
#  ('setting', 223),
#  ('inches', 222),
#  ('wall', 222),
#  ('behind', 222),
#  ('solid', 222),
#  ('star', 221),
#  ('teething', 221),
#  ('style', 221),
#  ('clear', 221),
#  ('pumping', 221),
#  ('foot', 220),
#  ('fill', 220),
#  ('either.', 220),
#  ('machine', 220),
#  ('elastic', 219),
#  ('plays', 219),
#  ('ok.', 219),
#  ('arm', 219),
#  ('leg', 219),
#  ('bassinet', 218),
#  ('absolutely', 217),
#  ('lights', 217),
#  ('in,', 217),
#  ('uncomfortable', 217),
#  ('loose', 217),
#  ('15', 216),
#  ('believe', 215),
#  ("hasn't", 215),
#  ('way.', 215),
#  ('age', 214),
#  ('broke', 214),
#  ('holder', 214),
#  ('starts', 213),
#  ('single', 213),
#  ('cup.', 213),
#  ('gift', 212),
#  ('ends', 212),
#  ('stays', 212),
#  ('mouth.', 212),
#  ('bottle.', 212),
#  ('difference', 212),
#  ('Dr.', 212),
#  ('ready', 211),
#  ('is,', 211),
#  ('later', 211),
#  ("we're", 211),
#  ('mostly', 211),
#  ('bibs', 211),
#  ('sheets', 210),
#  ('However', 210),
#  ('girl', 210),
#  ('seen', 209),
#  ('switch', 209),
#  ("you'll", 208),
#  ('lay', 207),
#  ('installed', 207),
#  ('favorite', 207),
#  ('harness', 207),
#  ('starting', 206),
#  ('size.', 206),
#  ('moving', 206),
#  ('bib', 206),
#  ('boy', 205),
#  ('fell', 205),
#  ('problem.', 205),
#  ('shower', 205),
#  ('toilet', 205),
#  ('these,', 204),
#  ('actual', 204),
#  ('toys.', 204),
#  ('parents', 203),
#  ('trouble', 203),
#  ('wants', 203),
#  ('awkward', 203),
#  ('body', 203),
#  ('surface', 202),
#  ('basically', 202),
#  ('fully', 202),
#  ('life', 202),
#  ('soft,', 202),
#  ('silicone', 201),
#  ('blankets', 201),
#  ('green', 201),
#  ('is.', 200),
#  ('straight', 200),
#  ('volume', 200),
#  ('metal', 200),
#  ('fit.', 200),
#  ('black', 200),
#  ('20', 199),
#  ('somewhat', 198),
#  ('power', 198),
#  ('buttons', 198),
#  ('interest', 198),
#  ('sent', 198),
#  ('dishwasher', 198),
#  ('recline', 198),
#  ('enough.', 197),
#  ('understand', 196),
#  ('red', 196),
#  ('normal', 196),
#  ('teether', 195),
#  ('folds', 195),
#  ('near', 195),
#  ('customer', 195),
#  ('helps', 194),
#  ('30', 194),
#  ('quality.', 194),
#  ('watch', 194),
#  ('reading', 193),
#  ('(or', 193),
#  ('stop', 193),
#  ('sun', 193),
#  ('young', 192),
#  ('be.', 192),
#  ('options', 192),
#  ('send', 192),
#  ('above', 191),
#  ('grab', 191),
#  ('room.', 191),
#  ('paid', 191),
#  ('quick', 191),
#  ('properly', 191),
#  ('across', 190),
#  ('for.', 190),
#  ('folded', 190),
#  ('otherwise', 190),
#  ('eventually', 190),
#  ('Although', 190),
#  ('stars.', 190),
#  ('you.', 189),
#  ("We've", 189),
#  ('towel', 189),
#  ('realized', 188),
#  ('diapers.', 188),
#  ('down,', 188),
#  ('touch', 188),
#  ('purchasing', 187),
#  ('certainly', 187),
#  ('night.', 187),
#  ('long.', 187),
#  ('day.', 186),
#  ('dirty', 186),
#  ('screw', 186),
#  ('good,', 186),
#  ('except', 186),
#  ('softer', 186),
#  ('careful', 186),
#  ('glass', 186),
#  ('canopy', 186),
#  ('phone', 185),
#  ('with.', 185),
#  ('description', 185),
#  ('wrong', 184),
#  ('bowl', 184),
#  ('instead.', 184),
#  ('wood', 184),
#  ('car.', 184),
#  ('realize', 183),
#  ('not.', 183),
#  ('major', 183),
#  ('temperature', 183),
#  ('pulled', 182),
#  ('turns', 182),
#  ('kitchen', 182),
#  ('angle', 182),
#  ('(not', 182),
#  ('fan', 182),
#  ('it!', 181),
#  ('lost', 181),
#  ('suck', 181),
#  ('small,', 181),
#  ('tip', 181),
#  ("daughter's", 180),
#  ('mom', 180),
#  ('flimsy', 180),
#  ('But,', 180),
#  ('adjustable', 180),
#  ('pop', 180),
#  ('cover.', 179),
#  ('clothes', 179),
#  ('worry', 178),
#  ('mesh', 178),
#  ('child.', 177),
#  ('pulling', 177),
#  ('pail', 177),
#  ('frame', 177),
#  ('together.', 176),
#  ('knew', 176),
#  ('tape', 175),
#  ('center', 175),
#  ('VERY', 175),
#  ('carrying', 175),
#  ('size,', 175),
#  ('prefers', 175),
#  ('sized', 175),
#  ('level', 175),
#  ('recommended', 174),
#  ('walk', 174),
#  ('show', 174),
#  ('booster', 174),
#  ('asleep', 174),
#  ('Ergo', 174),
#  ('cause', 173),
#  ('returning', 173),
#  ('Price', 173),
#  ('to.', 173),
#  ('edge', 173),
#  ('padding', 173),
#  ('smooth', 173),
#  ('waste', 172),
#  ('allows', 172),
#  ('shopping', 172),
#  ('diapers,', 172),
#  ('nice.', 171),
#  ('original', 171),
#  ('durable', 171),
#  ('pacifiers', 171),
#  ('buckle', 171),
#  ('soft.', 170),
#  ('son.', 170),
#  ('screen', 170),
#  ('thicker', 170),
#  ('pink', 170),
#  ('wait', 170),
#  ('Love', 170),
#  ('snack', 170),
#  ('added', 169),
#  ('tub.', 169),
#  ('cute.', 169),
#  ('mechanism', 169),
#  ('handy', 169),
#  ('do.', 169),
#  ('expecting', 169),
#  ('back,', 169),
#  ('toy,', 168),
#  ('Great', 168),
#  ('model', 168),
#  ('likely', 168),
#  ('Fisher', 168),
#  ('additional', 167),
#  ('covered', 166),
#  ('dont', 166),
#  ('running', 166),
#  ...]

# %%
four_text
# Out:
# [('is', 67529),
#  ('', 66769),
#  ('are', 23222),
#  ('was', 21684),
#  ('baby', 15095),
#  ('very', 12862),
#  ('little', 12043),
#  ('has', 10639),
#  ('had', 10320),
#  ('really', 10136),
#  ('more', 9428),
#  ('great', 8365),
#  ('easy', 7979),
#  ("don't", 7860),
#  ('seat', 7795),
#  ('it.', 7124),
#  ('put', 6856),
#  ('still', 6379),
#  ('much', 6353),
#  ('too', 6119),
#  ('-', 5952),
#  ('son', 5877),
#  ('used', 5804),
#  ('does', 5776),
#  ('love', 5630),
#  ("doesn't", 5315),
#  ('old', 5186),
#  ('using', 5039),
#  ('were', 4899),
#  ('been', 4839),
#  ('off', 4821),
#  ("I'm", 4800),
#  ('bought', 4779),
#  ('fit', 4707),
#  ('nice', 4695),
#  ('daughter', 4556),
#  ('bit', 4544),
#  ('months', 4543),
#  ('car', 4471),
#  ('keep', 4287),
#  ('around', 4258),
#  ('stroller', 4188),
#  ('need', 4079),
#  ('am', 4075),
#  ("didn't", 4071),
#  ('enough', 4015),
#  ('while', 3991),
#  ('diaper', 3984),
#  ('got', 3936),
#  ('few', 3891),
#  ('since', 3823),
#  ('pretty', 3812),
#  ('small', 3739),
#  ('down', 3682),
#  ('4', 3641),
#  ('bag', 3580),
#  ('2', 3519),
#  ('big', 3448),
#  ('better', 3398),
#  ('wish', 3348),
#  ('product', 3340),
#  ('did', 3325),
#  ('seems', 3312),
#  ('works', 3248),
#  ('bottles', 3192),
#  ('thing', 3176),
#  ('it,', 3165),
#  ('hard', 3140),
#  ('sure', 3122),
#  ('size', 3110),
#  ('able', 3100),
#  ('without', 3096),
#  ('bottle', 3077),
#  ('hold', 3057),
#  ('lot', 3041),
#  ('5', 2928),
#  ('month', 2919),
#  ('side', 2877),
#  ('made', 2839),
#  ("can't", 2835),
#  ('recommend', 2832),
#  ('loves', 2812),
#  ('buy', 2786),
#  ('easily', 2744),
#  ('long', 2715),
#  ("I've", 2686),
#  ('child', 2647),
#  ('top', 2633),
#  ('being', 2614),
#  ('right', 2574),
#  ('something', 2554),
#  ('makes', 2533),
#  ('cover', 2525),
#  ('find', 2523),
#  ('3', 2517),
#  ('getting', 2471),
#  ('cup', 2445),
#  ('before', 2419),
#  ('through', 2416),
#  ('different', 2393),
#  ('plastic', 2392),
#  ('well.', 2381),
#  ('room', 2351),
#  ('water', 2335),
#  ('both', 2324),
#  ('stars', 2308),
#  ('soft', 2298),
#  ('going', 2284),
#  ('having', 2279),
#  ('every', 2245),
#  ('gets', 2220),
#  ('set', 2215),
#  ("isn't", 2211),
#  ('fits', 2201),
#  ('found', 2200),
#  ('clean', 2199),
#  ('where', 2198),
#  ('never', 2170),
#  ('quite', 2147),
#  ('another', 2128),
#  ('play', 2122),
#  ('toy', 2064),
#  ('crib', 2056),
#  ('though', 2050),
#  ('once', 2045),
#  ('feel', 2038),
#  ('actually', 2028),
#  ('many', 2008),
#  ('things', 1996),
#  ('perfect', 1975),
#  ('definitely', 1972),
#  ('always', 1970),
#  ('However,', 1966),
#  ('comes', 1940),
#  ('seem', 1937),
#  ('same', 1927),
#  ('far', 1926),
#  ('toys', 1913),
#  ('price', 1908),
#  ('bottom', 1907),
#  ('happy', 1874),
#  ('may', 1858),
#  ('purchased', 1856),
#  ('wash', 1855),
#  ('likes', 1852),
#  ('high', 1842),
#  ('tried', 1839),
#  ('problem', 1837),
#  ('chair', 1827),
#  ('them.', 1821),
#  ('&', 1821),
#  ('monitor', 1819),
#  ('part', 1814),
#  ('those', 1812),
#  ('looking', 1809),
#  ('quality', 1757),
#  ('extra', 1751),
#  ('food', 1744),
#  ('looks', 1744),
#  ('light', 1728),
#  ('comfortable', 1707),
#  ('pump', 1703),
#  ('place', 1695),
#  ("baby's", 1691),
#  ('thought', 1685),
#  ('probably', 1685),
#  ('head', 1670),
#  ('easier', 1657),
#  ('less', 1652),
#  ('changing', 1641),
#  ('until', 1634),
#  ('under', 1624),
#  ('front', 1609),
#  ('best', 1601),
#  ('large', 1599),
#  ('should', 1592),
#  ('try', 1589),
#  ('took', 1588),
#  ('almost', 1585),
#  ('might', 1584),
#  ('cute', 1580),
#  ('came', 1574),
#  ('reason', 1572),
#  ('wanted', 1569),
#  ('times', 1566),
#  ('open', 1562),
#  ('sleep', 1549),
#  ('started', 1542),
#  ('diapers', 1541),
#  ('straps', 1522),
#  ('6', 1522),
#  ('milk', 1521),
#  ('worth', 1519),
#  ('difficult', 1518),
#  ('sit', 1514),
#  ('night', 1503),
#  ("I'd", 1493),
#  ("you're", 1482),
#  ('tray', 1475),
#  ('pull', 1462),
#  ("that's", 1449),
#  ('super', 1435),
#  ('couple', 1434),
#  ("haven't", 1434),
#  ('each', 1430),
#  ('kids', 1416),
#  ('last', 1413),
#  ('babies', 1413),
#  ('time.', 1409),
#  ('instead', 1406),
#  ('baby.', 1405),
#  ('ones', 1401),
#  ('between', 1396),
#  ('fabric', 1395),
#  ('move', 1390),
#  ('turn', 1387),
#  ('pillow', 1385),
#  ('infant', 1383),
#  ('great.', 1376),
#  ('husband', 1368),
#  ('seat.', 1363),
#  ('out.', 1357),
#  ('cloth', 1357),
#  ('complaint', 1353),
#  ("won't", 1347),
#  ('pad', 1339),
#  ('color', 1337),
#  ('toddler', 1337),
#  ('help', 1327),
#  ('smaller', 1327),
#  ('especially', 1327),
#  ('second', 1312),
#  ('gave', 1310),
#  ('inside', 1308),
#  ("wasn't", 1307),
#  ('trying', 1306),
#  ('needed', 1304),
#  ('takes', 1288),
#  ('worked', 1284),
#  ('several', 1277),
#  ('Baby', 1271),
#  ('music', 1259),
#  ('issue', 1256),
#  ('longer', 1241),
#  ('sometimes', 1240),
#  ('kind', 1238),
#  ("wouldn't", 1236),
#  ('own', 1229),
#  ('strap', 1221),
#  ('gate', 1219),
#  ('one.', 1216),
#  ('reviews', 1204),
#  ('use.', 1203),
#  ('regular', 1188),
#  ('handle', 1184),
#  ('material', 1183),
#  ('design', 1181),
#  ('away', 1177),
#  ('hand', 1174),
#  ('cups', 1174),
#  ('mattress', 1167),
#  ('swing', 1164),
#  ('why', 1163),
#  ('older', 1154),
#  ('end', 1153),
#  ('stay', 1148),
#  ('product.', 1125),
#  ('change', 1119),
#  ('everything', 1112),
#  ('next', 1108),
#  ('during', 1106),
#  ('up.', 1104),
#  ('liked', 1103),
#  ('sound', 1102),
#  ('1', 1100),
#  ('carry', 1093),
#  ('nipple', 1092),
#  ('fold', 1085),
#  ('bigger', 1081),
#  ('pack', 1080),
#  ('Also,', 1079),
#  ('wipes', 1079),
#  ('loved', 1070),
#  ('bags', 1069),
#  ('travel', 1064),
#  ('sippy', 1062),
#  ('rather', 1060),
#  ('three', 1054),
#  ('weeks', 1052),
#  ('fine', 1052),
#  ('anything', 1051),
#  ('yet', 1050),
#  ('keeps', 1049),
#  ('sturdy', 1047),
#  ('weight', 1037),
#  ('putting', 1031),
#  ('job', 1027),
#  ('together', 1022),
#  ('tub', 1019),
#  ('space', 1018),
#  ('feature', 1013),
#  ('larger', 1007),
#  ('hands', 1001),
#  ('store', 1001),
#  ('colors', 997),
#  ('star', 996),
#  ('buying', 995),
#  ('push', 993),
#  ('carrier', 988),
#  ('purchase', 987),
#  ('close', 986),
#  ("he's", 984),
#  ('table', 976),
#  ('stroller.', 976),
#  ('piece', 969),
#  ('least', 969),
#  ('whole', 965),
#  ('Great', 964),
#  ('ordered', 964),
#  ('potty', 961),
#  ('remove', 953),
#  ('holds', 950),
#  ('parts', 949),
#  ('dry', 949),
#  ('already', 946),
#  ('newborn', 942),
#  ('me.', 940),
#  ('heavy', 939),
#  ('let', 938),
#  ('full', 932),
#  ('prefer', 932),
#  ('well,', 928),
#  ("they're", 924),
#  ('people', 922),
#  ('goes', 920),
#  ('read', 919),
#  ('fact', 918),
#  ('item', 918),
#  ('on.', 916),
#  ('decided', 915),
#  ('seats', 913),
#  ('went', 906),
#  ('four', 905),
#  ('storage', 904),
#  ('though.', 900),
#  ('old.', 900),
#  ('bed', 897),
#  ('expensive', 890),
#  ('making', 888),
#  ('bag.', 887),
#  ('lid', 881),
#  ('too.', 881),
#  ('leave', 880),
#  ('needs', 875),
#  ('legs', 873),
#  ('onto', 870),
#  ('minutes', 868),
#  ('again', 867),
#  ('(I', 865),
#  ('sitting', 856),
#  ('covers', 856),
#  ('others', 855),
#  ('8', 855),
#  ('off.', 850),
#  ('breast', 847),
#  ('nipples', 846),
#  ('fall', 845),
#  ('seat,', 840),
#  ('although', 840),
#  ('white', 836),
#  ('that,', 835),
#  ('leak', 829),
#  ('10', 829),
#  ('home', 828),
#  ('velcro', 828),
#  ('either', 824),
#  ('straw', 823),
#  ('Very', 822),
#  ('this.', 821),
#  ('air', 821),
#  ('pocket', 821),
#  ('though,', 819),
#  ('problems', 817),
#  ('usually', 817),
#  ('house', 816),
#  ('said', 814),
#  ('price.', 814),
#  ('short', 814),
#  ('maybe', 812),
#  ("aren't", 811),
#  ('warm', 811),
#  ('hang', 800),
#  ('years', 799),
#  ('simple', 797),
#  ('safe', 797),
#  ('start', 796),
#  ("she's", 796),
#  ('wide', 795),
#  ('completely', 794),
#  ('(and', 792),
#  ('slightly', 791),
#  ('such', 790),
#  ('perfectly', 788),
#  ('middle', 787),
#  ('Britax', 786),
#  ('base', 783),
#  ('tight', 783),
#  ('camera', 782),
#  ('attach', 781),
#  ('seemed', 780),
#  ('stick', 778),
#  ('pieces', 777),
#  ('bad', 774),
#  ('due', 772),
#  ('sides', 772),
#  ('received', 771),
#  ('order', 771),
#  ('--', 771),
#  ('issues', 769),
#  ('months.', 769),
#  ('kid', 765),
#  ('baby,', 762),
#  ('support', 762),
#  ('huge', 761),
#  ('install', 761),
#  ('must', 759),
#  ('helps', 759),
#  ('it!', 758),
#  ('bath', 758),
#  ('deal', 755),
#  ('hot', 753),
#  ('point', 752),
#  ('sleeping', 751),
#  ('adjust', 751),
#  ('option', 751),
#  ('blanket', 748),
#  ('mat', 748),
#  ('system', 747),
#  ('review', 747),
#  ("couldn't", 747),
#  ('clean.', 741),
#  ('in.', 735),
#  ('amount', 733),
#  ('often', 731),
#  ('held', 729),
#  ('attached', 727),
#  ('fairly', 724),
#  ('figure', 723),
#  ('holding', 721),
#  ('washing', 721),
#  ('quickly', 720),
#  ('video', 718),
#  ('button', 714),
#  ('keeping', 713),
#  ('all,', 713),
#  ('case', 712),
#  ('add', 709),
#  ('done', 706),
#  ('wipe', 706),
#  ('wear', 705),
#  ('snap', 704),
#  ('Easy', 703),
#  ('unit', 701),
#  ('(which', 701),
#  ('suction', 700),
#  ('them,', 699),
#  ('Overall,', 699),
#  ('items', 699),
#  ('mobile', 698),
#  ('height', 698),
#  ('carseat', 698),
#  ('time,', 697),
#  ('fine.', 693),
#  ('again.', 693),
#  ('half', 692),
#  ('battery', 691),
#  ('bottles.', 691),
#  ('flat', 691),
#  ('ended', 687),
#  ('smell', 685),
#  ('7', 684),
#  ('great,', 682),
#  ('up,', 681),
#  ('itself', 680),
#  ('fun', 677),
#  ('wheels', 676),
#  ('favorite', 675),
#  ('out,', 673),
#  ('against', 673),
#  ('Graco', 673),
#  ('cannot', 672),
#  ('glad', 672),
#  ("we've", 671),
#  ('bar', 669),
#  ('facing', 666),
#  ('brush', 666),
#  ('washed', 665),
#  ('doing', 665),
#  ('that.', 665),
#  ('safety', 664),
#  ("there's", 664),
#  ('feet', 662),
#  ('exactly', 661),
#  ('face', 658),
#  ('feeding', 657),
#  ('taking', 656),
#  ('money', 655),
#  ('insert', 655),
#  ('door', 651),
#  ('basket', 650),
#  ('box', 649),
#  ('nothing', 648),
#  ('brand', 648),
#  ('days', 647),
#  ('pain', 647),
#  ('stuff', 646),
#  ('said,', 646),
#  ('reach', 645),
#  ("I'll", 645),
#  ('noise', 645),
#  ('this,', 644),
#  ('months,', 644),
#  ('floor', 643),
#  ('guess', 643),
#  ('mind', 642),
#  ('kept', 639),
#  ('secure', 639),
#  ('easily.', 636),
#  ('mirror', 636),
#  ('useful', 633),
#  ('etc.', 631),
#  ('use,', 631),
#  ('sheet', 631),
#  ('here', 629),
#  ('double', 628),
#  ('tall', 626),
#  ('picture', 626),
#  ('stand', 624),
#  ('left', 623),
#  ('feels', 623),
#  ('forward', 620),
#  ("son's", 620),
#  ('bright', 617),
#  ("We've", 616),
#  ('Love', 615),
#  ('giving', 614),
#  ('wet', 612),
#  ('position', 611),
#  ('given', 611),
#  ('worry', 610),
#  ('better.', 608),
#  ('9', 608),
#  ('batteries', 607),
#  ('now.', 606),
#  ('free', 606),
#  ('stays', 603),
#  ('standard', 601),
#  ('Overall', 600),
#  ('thin', 600),
#  ('Once', 599),
#  ('week', 599),
#  ('looked', 598),
#  ('overall', 596),
#  ('stroller,', 596),
#  ('run', 595),
#  ('along', 595),
#  ('Amazon', 594),
#  ('harness', 594),
#  ('area', 593),
#  ('chew', 592),
#  ('rest', 592),
#  ('thick', 592),
#  ('ever', 590),
#  ('old,', 589),
#  ('Medela', 589),
#  ('all.', 588),
#  ('mouth', 584),
#  ('tell', 583),
#  ('idea', 583),
#  ('shape', 582),
#  ('throw', 579),
#  ('supposed', 579),
#  ('on,', 579),
#  ('room.', 578),
#  ('outside', 576),
#  ('cheap', 576),
#  ('folds', 575),
#  ('playing', 574),
#  ('me,', 573),
#  ('however', 573),
#  ('cold', 573),
#  ('real', 572),
#  ('parent', 572),
#  ('sounds', 572),
#  ('clear', 572),
#  ('nursing', 570),
#  ('means', 570),
#  ('five', 568),
#  ('drink', 568),
#  ('stuck', 567),
#  ('bassinet', 567),
#  ('hear', 563),
#  ('however,', 561),
#  ('noticed', 560),
#  ('holder', 559),
#  ('clip', 558),
#  ('handles', 557),
#  ('highly', 556),
#  ('low', 556),
#  ('instructions', 555),
#  ('else', 552),
#  ('down.', 551),
#  ('figured', 550),
#  ('pockets', 549),
#  ('allows', 547),
#  ('now,', 545),
#  ('care', 545),
#  ('main', 544),
#  ('slide', 544),
#  ('features', 544),
#  ('turned', 543),
#  ('zipper', 543),
#  ('compared', 541),
#  (':)', 541),
#  ('unless', 538),
#  ('rear', 538),
#  ('uses', 537),
#  ('opening', 537),
#  ('lock', 537),
#  ('nicely', 536),
#  ('lights', 535),
#  ('parents', 532),
#  ('absolutely', 532),
#  ('good.', 532),
#  ('bottles,', 531),
#  ("we're", 531),
#  ("hasn't", 530),
#  ('pleased', 530),
#  ('shower', 529),
#  ('cleaning', 529),
#  ('him.', 528),
#  ('tiny', 526),
#  ('one,', 526),
#  ('reviewers', 526),
#  ('shoulder', 526),
#  ('lots', 523),
#  ('working', 523),
#  ('strong', 522),
#  ('type', 521),
#  ('solid', 521),
#  ('latch', 521),
#  ('belt', 520),
#  ('pacifier', 520),
#  ('wrap', 519),
#  ('cut', 519),
#  ('arms', 518),
#  ('blue', 518),
#  ('neck', 518),
#  ('gift', 517),
#  ('price,', 517),
#  ('flow', 517),
#  ('formula', 515),
#  ('plus', 515),
#  ('live', 515),
#  ('asleep', 514),
#  ('these.', 514),
#  ('says', 512),
#  ('dishwasher', 512),
#  ('designed', 511),
#  ('apart', 511),
#  ('there.', 510),
#  ('similar', 508),
#  ('children', 508),
#  ('quick', 507),
#  ('felt', 506),
#  ('around.', 505),
#  ('handy', 504),
#  ('Avent', 502),
#  ('crib.', 501),
#  ('bulky', 501),
#  ('Since', 499),
#  ('enjoy', 498),
#  ('cheaper', 495),
#  ('expect', 495),
#  ('wall', 495),
#  ('teething', 492),
#  ('gotten', 490),
#  ('annoying', 490),
#  ('grab', 490),
#  ('allow', 489),
#  ('green', 487),
#  ('warmer', 487),
#  ('carrying', 486),
#  ('us.', 485),
#  ('(the', 484),
#  ('entire', 484),
#  ('pick', 483),
#  ('her.', 483),
#  ('snaps', 482),
#  ('sun', 482),
#  ('mom', 479),
#  ('roll', 479),
#  ('rubber', 479),
#  ('machine', 479),
#  ('toilet', 478),
#  ('chair.', 478),
#  ('plan', 476),
#  ('ready', 475),
#  ('While', 474),
#  ('in,', 473),
#  ('replace', 473),
#  ('life', 473),
#  ('pads', 473),
#  ('convenient', 472),
#  ('volume', 472),
#  ('sits', 472),
#  ('booster', 472),
#  ('falls', 471),
#  ('extremely', 471),
#  ('feed', 471),
#  ('decent', 468),
#  ('fast', 465),
#  ('products', 465),
#  ('simply', 463),
#  ('break', 462),
#  ('boy', 460),
#  ('lower', 460),
#  ('holes', 459),
#  ('So,', 459),
#  ('mine', 458),
#  ('night.', 457),
#  ('off,', 457),
#  ('dirty', 456),
#  ('much.', 455),
#  ('black', 455),
#  ('bag,', 454),
#  ('bib', 454),
#  ('hours', 452),
#  ('padding', 452),
#  ('starting', 451),
#  ('switch', 451),
#  ('multiple', 451),
#  ('side.', 450),
#  ('prevent', 450),
#  ('pop', 448),
#  ('size.', 448),
#  ('pay', 448),
#  ('line', 447),
#  ('foam', 446),
#  ('someone', 446),
#  ('check', 446),
#  ('toy.', 446),
#  ('20', 446),
#  ('product,', 445),
#  ('pumping', 444),
#  ('Dr.', 444),
#  ('myself', 443),
#  ('bottle.', 442),
#  ('girl', 442),
#  ('cost', 442),
#  ('spend', 441),
#  ('cotton', 441),
#  ('sheets', 439),
#  ('day.', 439),
#  ('loud', 437),
#  ('strollers', 437),
#  ('foot', 437),
#  ('side,', 436),
#  ('plays', 435),
#  ('place.', 435),
#  ('mesh', 434),
#  ('model', 433),
#  ('back.', 433),
#  ('seen', 433),
#  ('single', 432),
#  ('added', 431),
#  ('15', 430),
#  ('soon', 429),
#  ('kitchen', 429),
#  ('nice.', 429),
#  ('snack', 428),
#  ('adjustable', 427),
#  ('installed', 426),
#  ('pail', 425),
#  ('plenty', 425),
#  ('problem.', 424),
#  ('folded', 423),
#  ('hoping', 422),
#  ('moving', 422),
#  ('underneath', 421),
#  ('worried', 420),
#  ('liquid', 420),
#  ('finally', 419),
#  ('version', 419),
#  ('trouble', 418),
#  ('purchase.', 417),
#  ('soft,', 417),
#  ('sort', 417),
#  ('hanging', 416),
#  ('across', 416),
#  ('oz', 416),
#  ('sized', 415),
#  ('inches', 415),
#  ('anyone', 413),
#  ('clean,', 413),
#  ('gives', 413),
#  ('shopping', 412),
#  ('helpful', 411),
#  ('important', 411),
#  ('coming', 411),
#  ('great!', 410),
#  ('car.', 410),
#  ('lightweight', 410),
#  ('together.', 408),
#  ('level', 407),
#  ('screw', 407),
#  ('behind', 407),
#  ("daughter's", 404),
#  ('yet,', 404),
#  ('setting', 402),
#  ('spoon', 402),
#  ('stars.', 401),
#  ('toys.', 401),
#  ('body', 401),
#  ('cool', 401),
#  ('starts', 400),
#  ('careful', 400),
#  ('red', 400),
#  ('except', 399),
#  ('30', 399),
#  ('fully', 398),
#  ('helped', 397),
#  ('reading', 397),
#  ('within', 397),
#  ('yet.', 396),
#  ('diapers,', 395),
#  ("you'll", 394),
#  ('bibs', 394),
#  ('hole', 393),
#  ('otherwise', 393),
#  ('recline', 393),
#  ('fill', 392),
#  ('wants', 392),
#  ('nearly', 392),
#  ('diapers.', 391),
#  ('hit', 391),
#  ('replacement', 390),
#  ('options', 390),
#  ('enjoys', 390),
#  ('eat', 390),
#  ('liner', 390),
#  ('lay', 390),
#  ('wood', 389),
#  ('higher', 388),
#  ('saw', 388),
#  ('canopy', 388),
#  ('temperature', 387),
#  ('swaddle', 387),
#  ('Maybe', 386),
#  ('blankets', 386),
#  ('far.', 385),
#  ('way.', 385),
#  ('walk', 385),
#  ('spout', 385),
#  ('past', 384),
#  ("They're", 384),
#  ('mostly', 384),
#  ('cup.', 384),
#  ('to.', 383),
#  ('watch', 383),
#  ('leg', 383),
#  ('tend', 383),
#  ('is,', 381),
#  ('imagine', 380),
#  ('matter', 380),
#  ('believe', 380),
#  ('wife', 379),
#  ('cover.', 378),
#  ('cause', 378),
#  ('metal', 377),
#  ('glass', 377),
#  ('included', 377),
#  ('nice,', 376),
#  ('age', 375),
#  ('constantly', 375),
#  ('style', 375),
#  ('(not', 372),
#  ('(or', 372),
#  ('house.', 371),
#  ('harder', 371),
#  ('n', 371),
#  ('additional', 370),
#  ('bother', 370),
#  ('wearing', 370),
#  ('LOVE', 368),
#  ('clothes', 368),
#  ('durable', 367),
#  ('minor', 367),
#  ('tummy', 366),
#  ('work.', 366),
#  ('touch', 366),
#  ('straight', 365),
#  ('expected', 365),
#  ('save', 365),
#  ('1/2', 365),
#  ('comfortable.', 365),
#  ('more.', 364),
#  ('Diaper', 364),
#  ('loose', 364),
#  ('young', 363),
#  ('drop', 362),
#  ('compact', 362),
#  ('barely', 362),
#  ('pulling', 360),
#  ('child.', 359),
#  ('far,', 359),
#  ('buckle', 358),
#  ('guy', 358),
#  ('hope', 358),
#  ('liners', 358),
#  ('son.', 357),
#  ('turns', 357),
#  ('bring', 355),
#  ('born', 354),
#  ('removed', 354),
#  ('knew', 353),
#  ('purpose', 353),
#  ('near', 353),
#  ('recommended', 352),
#  ('likely', 352),
#  ('ring', 351),
#  ('smooth', 351),
#  ('certainly', 350),
#  ('stop', 350),
#  ('small.', 350),
#  ('totally', 350),
#  ('brands', 350),
#  ('cute,', 350),
#  ('bowl', 348),
#  ('arm', 346),
#  ('dont', 346),
#  ('monitor.', 346),
#  ('tip', 344),
#  ('umbrella', 344),
#  ('quality.', 342),
#  ('trip', 342),
#  ('enough.', 341),
#  ('grow', 341),
#  ('is.', 341),
#  ('running', 340),
#  ('original', 340),
#  ('negative', 339),
#  ('cute.', 338),
#  ('inserts', 337),
#  ('go.', 336),
#  ('later', 336),
#  ('window', 335),
#  ('soft.', 334),
#  ('separate', 333),
#  ('actual', 333),
#  ('VERY', 332),
#  ('removable', 332),
#  ('job.', 331),
#  ('Works', 331),
#  ('step', 331),
#  ('protect', 331),
#  ('living', 331),
#  ('shade', 331),
#  ('you.', 330),
#  ('mess', 330),
#  ('lift', 330),
#  ('above', 330),
#  ('silicone', 330),
#  ('downside', 329),
#  ('But,', 328),
#  ('normal', 327),
#  ('softer', 327),
#  ('perfect.', 327),
#  ('frame', 326),
#  ('provide', 325),
#  ('portable', 325),
#  ('wake', 325),
#  ('screen', 325),
#  ('become', 324),
#  ('pink', 324),
#  ('fan', 324),
#  ('size,', 324),
#  ('do.', 323),
#  ('center', 323),
#  ('edge', 323),
#  ('somewhat', 322),
#  ('complaints', 322),
#  ('taken', 321),
#  ('excellent', 320),
#  ('wait', 320),
#  ('small,', 319),
#  ('power', 319),
#  ('snug', 319),
#  ('upright', 319),
#  ('ease', 318),
#  ...]

# %%
five_text
# Out:
# [('', 155991),
#  ('is', 135812),
#  ('are', 55123),
#  ('was', 51550),
#  ('baby', 39066),
#  ('very', 29720),
#  ('has', 26912),
#  ('little', 24363),
#  ('had', 24191),
#  ('great', 23894),
#  ('love', 23380),
#  ('easy', 22910),
#  ('really', 18976),
#  ('more', 18561),
#  ('it.', 17625),
#  ('son', 16378),
#  ('put', 15575),
#  ('much', 15290),
#  ('old', 15206),
#  ('seat', 15036),
#  ("don't", 14872),
#  ('bought', 14653),
#  ('used', 14166),
#  ('still', 13975),
#  ('loves', 13694),
#  ('months', 13366),
#  ('-', 12878),
#  ('daughter', 12533),
#  ('using', 11922),
#  ('been', 11835),
#  ('too', 11380),
#  ('car', 10806),
#  ('were', 10485),
#  ('got', 10227),
#  ('keep', 10185),
#  ('recommend', 10160),
#  ('diaper', 9646),
#  ('around', 9606),
#  ('am', 9557),
#  ('enough', 9361),
#  ("I'm", 9358),
#  ('fit', 9325),
#  ('while', 9271),
#  ("doesn't", 9052),
#  ('nice', 8954),
#  ('since', 8880),
#  ('2', 8750),
#  ('off', 8739),
#  ('need', 8592),
#  ('stroller', 8377),
#  ('does', 8222),
#  ('without', 8195),
#  ('month', 8060),
#  ('perfect', 7943),
#  ('bag', 7820),
#  ("didn't", 7680),
#  ('every', 7590),
#  ('few', 7576),
#  ('bottles', 7565),
#  ('size', 7523),
#  ('buy', 7447),
#  ('soft', 7441),
#  ('small', 7316),
#  ('down', 7083),
#  ('hold', 6886),
#  ('product', 6879),
#  ('big', 6848),
#  ('made', 6838),
#  ("I've", 6800),
#  ('able', 6732),
#  ('easily', 6715),
#  ('works', 6661),
#  ('3', 6639),
#  ('bottle', 6627),
#  ('fits', 6538),
#  ('it,', 6354),
#  ('never', 6301),
#  ('different', 6274),
#  ('did', 6192),
#  ('many', 6188),
#  ('makes', 6174),
#  ('right', 6158),
#  ('lot', 6141),
#  ('thing', 6118),
#  ('clean', 6077),
#  ('better', 5942),
#  ('long', 5903),
#  ('well.', 5813),
#  ('sure', 5758),
#  ('best', 5656),
#  ("can't", 5642),
#  ('getting', 5619),
#  ('play', 5609),
#  ('room', 5549),
#  ('toy', 5536),
#  ('crib', 5526),
#  ('happy', 5507),
#  ('child', 5491),
#  ('bit', 5483),
#  ('wash', 5467),
#  ('before', 5464),
#  ('toys', 5423),
#  ('through', 5402),
#  ('purchased', 5386),
#  ('both', 5350),
#  ('being', 5272),
#  ('having', 5230),
#  ('another', 5213),
#  ('set', 5197),
#  ('cover', 5189),
#  ('water', 5176),
#  ('worth', 5174),
#  ('side', 5132),
#  ('find', 5122),
#  ('always', 5098),
#  ('4', 5089),
#  ('&', 5029),
#  ('tried', 5029),
#  ('pretty', 4987),
#  ('them.', 4959),
#  ('found', 4942),
#  ('going', 4934),
#  ('seems', 4836),
#  ('sleep', 4786),
#  ('definitely', 4768),
#  ('something', 4738),
#  ('super', 4716),
#  ('top', 4689),
#  ('pump', 4680),
#  ('Great', 4671),
#  ('things', 4653),
#  ('changing', 4587),
#  ('actually', 4582),
#  ('5', 4579),
#  ('hard', 4565),
#  ('started', 4396),
#  ('cup', 4391),
#  ('it!', 4380),
#  ('comfortable', 4329),
#  ('those', 4324),
#  ('feel', 4311),
#  ('looking', 4291),
#  ('extra', 4273),
#  ('6', 4269),
#  ('food', 4259),
#  ('great.', 4256),
#  ('high', 4235),
#  ('quality', 4203),
#  ('gets', 4194),
#  ('looks', 4191),
#  ('plastic', 4175),
#  ('far', 4162),
#  ("baby's", 4154),
#  ('chair', 4141),
#  ('comes', 4109),
#  ('where', 4095),
#  ('price', 4058),
#  ('wish', 4041),
#  ('highly', 4027),
#  ('loved', 3993),
#  ('almost', 3957),
#  ('once', 3954),
#  ('night', 3944),
#  ('ones', 3939),
#  ('cute', 3862),
#  ('Love', 3832),
#  ('same', 3815),
#  ('cloth', 3805),
#  ('kids', 3795),
#  ('until', 3781),
#  ('baby.', 3777),
#  ('time.', 3769),
#  ('diapers', 3760),
#  ('babies', 3687),
#  ('came', 3678),
#  ('likes', 3630),
#  ('too.', 3616),
#  ('times', 3578),
#  ('easier', 3527),
#  ('second', 3511),
#  ('several', 3508),
#  ('wanted', 3497),
#  ('large', 3457),
#  ('thought', 3449),
#  ('needed', 3432),
#  ('quite', 3422),
#  ('light', 3422),
#  ('each', 3410),
#  ('Very', 3388),
#  ('sit', 3380),
#  ('husband', 3359),
#  ('took', 3337),
#  ('keeps', 3324),
#  ('one.', 3323),
#  ('head', 3295),
#  ('milk', 3275),
#  ('place', 3261),
#  ('bottom', 3260),
#  ('part', 3258),
#  ('everything', 3250),
#  ("isn't", 3237),
#  ('toddler', 3231),
#  ('colors', 3195),
#  ('less', 3194),
#  ('last', 3131),
#  ('Baby', 3112),
#  ('under', 3107),
#  ('pad', 3094),
#  ('mattress', 3068),
#  ('reviews', 3066),
#  ('try', 3057),
#  ('glad', 3051),
#  ('own', 3037),
#  ('color', 3027),
#  ('though', 2982),
#  ('infant', 2976),
#  ('pack', 2921),
#  ('help', 2915),
#  ('product.', 2884),
#  ("haven't", 2869),
#  ('seat.', 2868),
#  ('buying', 2862),
#  ('couple', 2857),
#  ('problem', 2838),
#  ('front', 2817),
#  ('weeks', 2801),
#  ('during', 2793),
#  ('straps', 2790),
#  ('hands', 2759),
#  ('use.', 2759),
#  ('purchase', 2758),
#  ('favorite', 2757),
#  ('old.', 2751),
#  ('cups', 2749),
#  ('hand', 2744),
#  ('perfectly', 2731),
#  ('years', 2725),
#  ('ordered', 2709),
#  ('move', 2698),
#  ('especially', 2687),
#  ('change', 2685),
#  ('worked', 2681),
#  ('out.', 2680),
#  ('fabric', 2666),
#  ('three', 2665),
#  ('open', 2661),
#  ('seem', 2660),
#  ('between', 2657),
#  ('Easy', 2631),
#  ('went', 2621),
#  ('decided', 2619),
#  ('regular', 2614),
#  ('inside', 2613),
#  ("won't", 2610),
#  ('pull', 2609),
#  ('trying', 2607),
#  ('must', 2598),
#  ('bath', 2589),
#  ('sippy', 2583),
#  ('anything', 2571),
#  ('may', 2569),
#  ('should', 2561),
#  ('next', 2557),
#  ('carry', 2549),
#  ('dry', 2542),
#  ('monitor', 2534),
#  ('yet', 2533),
#  ('holds', 2528),
#  ('potty', 2519),
#  ('bags', 2518),
#  ('tub', 2499),
#  ('this.', 2496),
#  ('away', 2487),
#  ('home', 2477),
#  ('pillow', 2474),
#  ('table', 2466),
#  ('blanket', 2465),
#  ('breast', 2463),
#  ('1', 2452),
#  ("he's", 2444),
#  ('older', 2433),
#  ('sturdy', 2427),
#  ('probably', 2423),
#  ('house', 2420),
#  ("you're", 2419),
#  ('absolutely', 2414),
#  ("wasn't", 2413),
#  ('music', 2413),
#  ('tray', 2401),
#  ('turn', 2387),
#  ('store', 2376),
#  ('travel', 2344),
#  ("I'd", 2333),
#  ('newborn', 2325),
#  ('bed', 2324),
#  ('might', 2317),
#  ('longer', 2306),
#  ('nipple', 2296),
#  ('item', 2273),
#  ('space', 2271),
#  ('8', 2267),
#  ('safe', 2265),
#  ('warm', 2262),
#  ('stay', 2257),
#  ('wipes', 2253),
#  ("that's", 2250),
#  ('LOVE', 2245),
#  ('clean.', 2240),
#  ('material', 2233),
#  ('up.', 2232),
#  ('smaller', 2230),
#  ('ever', 2225),
#  ('takes', 2223),
#  ('let', 2220),
#  ('read', 2212),
#  ('people', 2194),
#  ('goes', 2179),
#  ("wouldn't", 2173),
#  ('design', 2172),
#  ('such', 2171),
#  ('these.', 2157),
#  ('weight', 2137),
#  ('fun', 2135),
#  ('gift', 2132),
#  ('worry', 2132),
#  ('already', 2127),
#  (':)', 2126),
#  ('swing', 2113),
#  ('simple', 2108),
#  ('10', 2103),
#  ('helps', 2101),
#  ('minutes', 2099),
#  ("couldn't", 2098),
#  ('stroller.', 2092),
#  ('gate', 2090),
#  ('handle', 2086),
#  ('held', 2076),
#  ('strap', 2065),
#  ('parts', 2064),
#  ('covers', 2060),
#  ('whole', 2056),
#  ('brand', 2053),
#  ('bag.', 2041),
#  ('putting', 2039),
#  ('end', 2039),
#  ('seats', 2038),
#  ('carrier', 2033),
#  ('months.', 2021),
#  ('on.', 2011),
#  ('instead', 2010),
#  ('hang', 1985),
#  ("she's", 1980),
#  ('etc.', 1979),
#  ("they're", 1960),
#  ('fact', 1955),
#  ('onto', 1949),
#  ('problems', 1940),
#  ('leave', 1938),
#  ('throw', 1934),
#  ('nipples', 1934),
#  ('sleeping', 1922),
#  ('sound', 1913),
#  ('well,', 1898),
#  ('together', 1896),
#  ('received', 1885),
#  ('holding', 1880),
#  ('expensive', 1877),
#  ('making', 1870),
#  ('shower', 1869),
#  ('liked', 1868),
#  ('fold', 1859),
#  ('full', 1854),
#  ('great!', 1845),
#  ('larger', 1838),
#  ('sitting', 1837),
#  ('least', 1836),
#  ('feeding', 1828),
#  ('chew', 1828),
#  ('washed', 1828),
#  ('washing', 1826),
#  ('7', 1815),
#  ('pocket', 1805),
#  ('teething', 1793),
#  ('storage', 1791),
#  ('fall', 1788),
#  ('bottles.', 1784),
#  ('(I', 1779),
#  ('items', 1779),
#  ('money', 1778),
#  ('stays', 1765),
#  ('white', 1762),
#  ('kind', 1758),
#  ('sometimes', 1758),
#  ('wipe', 1758),
#  ('again', 1749),
#  ('me.', 1740),
#  ('others', 1736),
#  ('Also,', 1735),
#  ('pacifier', 1722),
#  ('exactly', 1721),
#  ('(and', 1716),
#  ('needs', 1715),
#  ('hot', 1715),
#  ('attach', 1711),
#  ('air', 1700),
#  ('bigger', 1696),
#  ('However,', 1695),
#  ("We've", 1692),
#  ('Britax', 1691),
#  ('wear', 1690),
#  ('seat,', 1686),
#  ('feature', 1679),
#  ('remove', 1678),
#  ('uses', 1675),
#  ('close', 1675),
#  ('quickly', 1668),
#  ('baby,', 1655),
#  ('them,', 1654),
#  ('soft,', 1651),
#  ('sheet', 1649),
#  ('push', 1648),
#  ('all.', 1643),
#  ('huge', 1642),
#  ('attached', 1640),
#  ('nursing', 1638),
#  ('difficult', 1637),
#  ('done', 1635),
#  ("we've", 1633),
#  ('heavy', 1630),
#  ('free', 1629),
#  ('why', 1626),
#  ('piece', 1626),
#  ('start', 1623),
#  ("son's", 1622),
#  ('brush', 1616),
#  ('price.', 1612),
#  ('old,', 1605),
#  ('great,', 1602),
#  ('said', 1597),
#  ('issues', 1595),
#  ('base', 1593),
#  ('months,', 1591),
#  ('legs', 1588),
#  ('pumping', 1587),
#  ('9', 1584),
#  ('bibs', 1581),
#  ('week', 1578),
#  ('playing', 1577),
#  ('time,', 1576),
#  ('stuff', 1576),
#  ('usually', 1570),
#  ('either', 1566),
#  ('kept', 1561),
#  ('mouth', 1558),
#  ('mom', 1556),
#  ('life', 1552),
#  ('days', 1550),
#  ('allows', 1550),
#  ('completely', 1550),
#  ('wet', 1547),
#  ('blankets', 1547),
#  ('install', 1545),
#  ('velcro', 1537),
#  ('use,', 1532),
#  ('girl', 1526),
#  ('Highly', 1521),
#  ('looked', 1520),
#  ('kid', 1518),
#  ('order', 1518),
#  ('products', 1515),
#  ('lots', 1515),
#  ('floor', 1514),
#  ('case', 1512),
#  ('mat', 1512),
#  ('middle', 1510),
#  ('keeping', 1506),
#  ('bright', 1504),
#  ('boy', 1504),
#  ('adjust', 1496),
#  ('amount', 1493),
#  ('cold', 1492),
#  ('him.', 1482),
#  ('mobile', 1481),
#  ('along', 1480),
#  ('Medela', 1479),
#  ('add', 1477),
#  ('ready', 1474),
#  ('off.', 1469),
#  ('taking', 1467),
#  ('face', 1467),
#  ('anyone', 1465),
#  ('secure', 1461),
#  ('often', 1457),
#  ('gave', 1456),
#  ('fine', 1448),
#  ('booster', 1445),
#  ('dishwasher', 1442),
#  ('feels', 1438),
#  ('in.', 1437),
#  ('asleep', 1437),
#  ('rather', 1437),
#  ('leak', 1432),
#  ('reach', 1432),
#  ('folds', 1425),
#  ('Graco', 1421),
#  ('up,', 1420),
#  ('her.', 1419),
#  ('perfectly.', 1418),
#  ('half', 1416),
#  ('job', 1416),
#  ('Amazon', 1415),
#  ('tell', 1412),
#  ('safety', 1411),
#  ('formula', 1410),
#  ('hours', 1407),
#  ('feed', 1405),
#  ('sides', 1404),
#  ('toy.', 1401),
#  ('--', 1399),
#  ('doing', 1395),
#  ('stick', 1395),
#  ('grab', 1393),
#  ('room.', 1393),
#  ('due', 1387),
#  ('crib.', 1386),
#  ('nicely', 1386),
#  ('sheets', 1385),
#  ('flat', 1384),
#  ('here', 1379),
#  ('parents', 1377),
#  ('height', 1376),
#  ('seemed', 1374),
#  ('friends', 1372),
#  ('pleased', 1372),
#  ('plays', 1371),
#  ('quick', 1368),
#  ('pieces', 1362),
#  ('issue', 1361),
#  ('children', 1358),
#  ('now.', 1356),
#  ("aren't", 1355),
#  ('smell', 1353),
#  ('thick', 1350),
#  ('bottles,', 1349),
#  ('wonderful', 1348),
#  ('Avent', 1345),
#  ('double', 1344),
#  ('mind', 1340),
#  ('one,', 1339),
#  ('(which', 1337),
#  ('support', 1337),
#  ('mirror', 1334),
#  ('extremely', 1330),
#  ('handy', 1326),
#  ('review', 1326),
#  ('this,', 1324),
#  ('system', 1323),
#  ('swaddle', 1323),
#  ('shape', 1318),
#  ('cannot', 1317),
#  ('saw', 1314),
#  ('plus', 1304),
#  ('door', 1303),
#  ('arms', 1303),
#  ('nothing', 1302),
#  ('run', 1299),
#  ('carseat', 1299),
#  ('easily.', 1298),
#  ('again.', 1296),
#  ('perfect.', 1294),
#  ('lid', 1293),
#  ('bad', 1290),
#  ('four', 1290),
#  ('friend', 1285),
#  ('live', 1284),
#  ('night.', 1284),
#  ('day.', 1282),
#  ('plenty', 1275),
#  ('stand', 1274),
#  ('standard', 1267),
#  ('bib', 1262),
#  ('out,', 1260),
#  ('machine', 1260),
#  ('recommended', 1253),
#  ('wide', 1253),
#  ('now,', 1248),
#  ('clean,', 1239),
#  ('snap', 1236),
#  ('against', 1230),
#  ('feet', 1226),
#  ('stroller,', 1226),
#  ('born', 1225),
#  ('tight', 1217),
#  ('finally', 1215),
#  ('cheaper', 1213),
#  ('pads', 1213),
#  ('ended', 1207),
#  ('tiny', 1204),
#  ('useful', 1200),
#  ('soon', 1200),
#  ('short', 1199),
#  ('cleaning', 1197),
#  ('helped', 1195),
#  ('us.', 1192),
#  ('turned', 1191),
#  ('totally', 1188),
#  ('prefer', 1186),
#  ('sleeps', 1184),
#  ('else', 1182),
#  ('purchase.', 1179),
#  ('eat', 1177),
#  ('that.', 1177),
#  ('left', 1174),
#  ('basket', 1174),
#  ('sounds', 1173),
#  ('cheap', 1173),
#  ('insert', 1168),
#  ('forward', 1166),
#  ('around.', 1165),
#  ('point', 1165),
#  ('durable', 1165),
#  ('multiple', 1165),
#  ('suction', 1161),
#  ('toys.', 1159),
#  ('house.', 1159),
#  ('clip', 1158),
#  ('worried', 1157),
#  ('lights', 1155),
#  ('noise', 1153),
#  ("daughter's", 1151),
#  ('option', 1151),
#  ('entire', 1150),
#  ('facing', 1149),
#  ('blue', 1147),
#  ('20', 1144),
#  ('clothes', 1144),
#  ('15', 1142),
#  ('wrap', 1142),
#  ('awesome', 1139),
#  ('kitchen', 1138),
#  ('deal', 1137),
#  ('dirty', 1135),
#  ('down.', 1135),
#  ('on,', 1126),
#  ('type', 1125),
#  ('gives', 1125),
#  ('soft.', 1125),
#  ('figure', 1124),
#  ('although', 1124),
#  ('all,', 1123),
#  ('box', 1123),
#  ('gotten', 1122),
#  ('drink', 1116),
#  ("I'll", 1115),
#  ('myself', 1113),
#  ('bag,', 1112),
#  ('care', 1111),
#  ('seen', 1111),
#  ('plan', 1109),
#  ('cotton', 1105),
#  ("we're", 1104),
#  ('there.', 1101),
#  ('single', 1101),
#  ('straw', 1098),
#  ('mine', 1097),
#  ('more.', 1096),
#  ('handles', 1096),
#  ('outside', 1094),
#  ('strong', 1093),
#  ('idea', 1092),
#  ('Dr.', 1092),
#  ('excellent', 1088),
#  ('chair.', 1088),
#  ('too!', 1087),
#  ('simply', 1079),
#  ("They're", 1077),
#  ('tall', 1077),
#  ('Once', 1076),
#  ("hasn't", 1076),
#  ('rest', 1073),
#  ('hear', 1072),
#  ('position', 1071),
#  ('roll', 1069),
#  ('guy', 1068),
#  ('slightly', 1066),
#  ('pockets', 1066),
#  ('real', 1065),
#  ('washes', 1061),
#  ('compared', 1060),
#  ('car.', 1059),
#  ('quality.', 1058),
#  ('pick', 1058),
#  ('shopping', 1057),
#  ('knew', 1054),
#  ('fine.', 1053),
#  ('felt', 1053),
#  ('area', 1051),
#  ('son.', 1047),
#  ('fast', 1045),
#  ('product!', 1044),
#  ('LOVES', 1044),
#  ('parent', 1043),
#  ('neck', 1041),
#  ('figured', 1040),
#  ('convenient', 1040),
#  ('maybe', 1037),
#  ('cut', 1036),
#  ('wants', 1035),
#  ('falls', 1033),
#  ('me,', 1031),
#  ('enjoy', 1027),
#  ('bottle.', 1027),
#  ('believe', 1017),
#  ('watch', 1016),
#  ('diapers.', 1015),
#  ('adjustable', 1014),
#  ('green', 1011),
#  ('drying', 1009),
#  ('spoon', 1008),
#  ('spend', 1007),
#  ('enjoys', 1006),
#  ('working', 1005),
#  ('zipper', 1001),
#  ('brands', 1001),
#  ("there's", 1001),
#  ('carrying', 1000),
#  ('itself', 998),
#  ('battery', 997),
#  ('replace', 995),
#  ('batteries', 993),
#  ('lay', 993),
#  ('low', 993),
#  ('Perfect', 992),
#  ('size.', 992),
#  ('family', 992),
#  ('bar', 991),
#  ('given', 986),
#  ('bassinet', 986),
#  ('allow', 983),
#  ('them!', 980),
#  ('starting', 978),
#  ('means', 978),
#  ('sits', 977),
#  ('hanging', 976),
#  ('pacifiers', 976),
#  ('across', 975),
#  ('button', 972),
#  ('clear', 972),
#  ('Works', 969),
#  ('similar', 968),
#  ('added', 966),
#  ('reading', 965),
#  ('recommend.', 965),
#  ('bring', 963),
#  ('comfortable.', 960),
#  ('Since', 958),
#  ('cute.', 958),
#  ('bulky', 957),
#  ('himself', 955),
#  ('thin', 950),
#  ('toilet', 949),
#  ('important', 944),
#  ('version', 944),
#  ('pain', 943),
#  ('snaps', 943),
#  ('lightweight', 943),
#  ('video', 941),
#  ('slide', 939),
#  ('(the', 938),
#  ('sun', 938),
#  ('wall', 936),
#  ('says', 934),
#  ('solid', 932),
#  ('features', 932),
#  ('tummy', 932),
#  ('wearing', 931),
#  ('1/2', 930),
#  ('harness', 930),
#  ('n', 929),
#  ('warmer', 929),
#  ('diapers,', 927),
#  ('hit', 927),
#  ('problem.', 925),
#  ('grow', 924),
#  ('trouble', 914),
#  ('shoulder', 914),
#  ('apart', 913),
#  ('prevent', 913),
#  ('walk', 911),
#  ('30', 911),
#  ('teeth', 910),
#  ('child.', 908),
#  ('eating', 907),
#  ('pop', 907),
#  ('past', 906),
#  ('flow', 906),
#  ('go.', 904),
#  ('daily', 901),
#  ('hospital', 900),
#  ('purchasing', 900),
#  ('that,', 899),
#  ('product,', 899),
#  ('young', 898),
#  ('constantly', 896),
#  ('with.', 896),
#  ('falling', 896),
#  ('slept', 895),
#  ('wait', 895),
#  ('complaint', 894),
#  ('spoons', 894),
#  ('latch', 889),
#  ('holder', 889),
#  ('wheels', 888),
#  ('herself', 887),
#  ('noticed', 887),
#  ('reason', 886),
#  ('better.', 886),
#  ('rubber', 883),
#  ('lock', 882),
#  ('this!', 881),
#  ('these,', 881),
#  ('comfy', 879),
#  ('yet,', 878),
#  ('unit', 877),
#  ('black', 877),
#  ('mesh', 876),
#  ('fairly', 873),
#  ('18', 872),
#  ('switch', 872),
#  ('stuck', 871),
#  ('within', 871),
#  ('check', 871),
#  ('Bought', 869),
#  ('picture', 867),
#  ('in,', 865),
#  ('daughter.', 863),
#  ('sleep.', 862),
#  ('save', 862),
#  ('fill', 861),
#  ('mouth.', 859),
#  ('rear', 859),
#  ('installed', 856),
#  ('burp', 856),
#  ('though,', 852),
#  ('someone', 852),
#  ('chewing', 849),
#  ('12', 847),
#  ('back.', 847),
#  ('reviewers', 846),
#  ('twins', 846),
#  ('pink', 846),
#  ('touch', 845),
#  ('sized', 839),
#  ('strollers', 838),
#  ('(we', 835),
#  ('learning', 835),
#  ('ago', 835),
#  ('wife', 834),
#  ('style', 833),
#  ('holes', 831),
#  ('too,', 830),
#  ('.', 830),
#  ('opening', 829),
#  ('saved', 827),
#  ('far.', 825),
#  ('instructions', 824),
#  ('giving', 823),
#  ('break', 823),
#  ('body', 822),
#  ('trip', 821),
#  ('coming', 819),
#  ('disposable', 817),
#  ('cute,', 817),
#  ('hook', 813),
#  ('easy.', 811),
#  ('designed', 810),
#  ('supposed', 807),
#  ('teether', 806),
#  ('table.', 806),
#  ('dont', 805),
#  ('cool', 804),
#  ('camera', 804),
#  ('difference', 803),
#  ('glass', 803),
#  ('yet.', 800),
#  ('line', 798),
#  ('liner', 798),
#  ('moving', 797),
#  ('cover.', 797),
#  ('Definitely', 796),
#  ('cost', 796),
#  ("you'll", 795),
#  ('price,', 795),
#  ('ring', 793),
#  ('babies.', 793),
#  ('sturdy.', 792),
#  ('bathroom', 791),
#  ('age', 791),
#  ('rack', 790),
#  ('imagine', 789),
#  ('matter', 789),
#  ('size,', 789),
#  ('recently', 788),
#  ('to.', 788),
#  ('immediately', 788),
#  ('lost', 786),
#  ('much.', 786),
#  ('snack', 783),
#  ('though.', 781),
#  ('wash.', 780),
#  ('good.', 778),
#  ('mess', 778),
#  ('place.', 777),
#  ('hurt', 776),
#  ('pump.', 776),
#  ('ones.', 775),
#  ('belt', 774),
#  ('later', 773),
#  ('five', 773),
#  ('While', 772),
#  ('bed.', 772),
#  ("He's", 772),
#  ('helpful', 769),
#  ('work.', 768),
#  ('way.', 766),
#  ('stars', 765),
#  ('together.', 765),
#  ('stop', 765),
#  ('arrived', 763),
#  ('amazing', 759),
#  ('oz', 758),
#  ('toys,', 756),
#  ('nice.', 755),
#  ('sets', 755),
#  ('everyone', 754),
#  ('become', 754),
#  ('summer', 754),
#  ('sturdy,', 754),
#  ('original', 753),
#  ('moved', 752),
#  ('off,', 752),
#  ('spout', 751),
#  ('softer', 750),
#  ('drop', 750),
#  ('fell', 748),
#  ('sink', 747),
#  ('behind', 746),
#  ('cause', 744),
#  ('money.', 742),
#  ('level', 742),
#  ('home.', 740),
#  ('living', 740),
#  ('waterproof', 738),
#  ('portable', 737),
#  ('have.', 736),
#  ('compact', 736),
#  ('early', 734),
#  ('tip', 734),
#  ('course', 733),
#  ('main', 731),
#  ('unless', 730),
#  ('tub.', 730),
#  ('wood', 730),
#  ('research', 729),
#  ('taken', 727),
#  ('originally', 725),
#  ('turns', 724),
#  ('options', 724),
#  ('book', 723),
#  ('nursery', 722),
#  ('nap', 721),
#  ('adorable', 721),
#  ('needed.', 720),
#  ('VERY', 720),
#  ('protect', 719),
#  ('step', 719),
#  ('anywhere', 718),
#  ('breastfeeding', 716),
#  ('underneath', 716),
#  ('(or', 715),
#  ('cup.', 715),
#  ('these!', 714),
#  ('learned', 713),
#  ('Fits', 713),
#  ('additional', 711),
#  ('thing.', 711),
#  ('inserts', 711),
#  ('bra', 711),
#  ('pay', 710),
#  ('quality,', 709),
#  ('away.', 708),
#  ('Plus', 705),
#  ('volume', 705),
#  ('far,', 702),
#  ('nearly', 701),
#  ('spent', 700),
#  ('foam', 700),
#  ('laundry', 700),
#  ('padding', 699),
#  ('training', 698),
#  ...]

# %%
##Cleans the words using the delete symbol function above
def clean(arr):
    array = []
    for word in arr:
        array.append(del_sym(str(word))) 
    return array

# %%
##word_ratings creates array of words associated with each rating
##num paramteter is the top whatsoever words
def word_ratings(txt, num):
    words = []
    i=0
    while i < num:     
        words.append(txt[i][0])
        i+=1
    return words

# %%
one_star = word_ratings(one_text, 500)
two_star = word_ratings(two_text, 500)
three_star = word_ratings(three_text, 500)
four_star = word_ratings(four_text, 500)
five_star = word_ratings(five_text, 500)

# %%
one = clean(one_star)
two = clean(two_star)
three = clean(three_star)
four = clean(four_star)
five = clean(five_star)

# %%
#another solution to solving getting rid of common/nonsignificant 
#words that do not have a positive or negative connotation
import matplotlib.pyplot as plt

def full_words(txt):
    array = []
    for i in txt:
        if len(i) == 2:
            first = del_sym(str(i[0]))
            second = i[1]
            new_item = (first, second)
            array.append(new_item)
    return array

test_one = full_words(one_text)
test_two = full_words(two_text)
test_three = full_words(three_text)
test_four = full_words(four_text)
test_five = full_words(five_text)

# %%
def point_value(review, one, two, three, four, five):
    value = 0
    words = review.split()
    length = len(words)
    best_words = []
    worst_words = []
    best_value = 0
    worst_value = 10
    indicator = False
    
    def best_worst(val):
        nonlocal best_value
        nonlocal worst_value
        nonlocal indicator
        
        if val >= best_value:
            best_value = val
            indicator = 1
            return True
        elif val <= worst_value:
            worst_value = val
            indicator = 0
            return True 
        return False
    
    def common_counter(word):
        common_words = 0
        if word in one:
            common_words+=1
        if word in two:
            common_words+=1
        if word in three:
            common_words+=1
        if word in four:
            common_words+=1
        if word in five:
            common_words+=1
        return common_words
    
    for i in range(length):
        common_count = common_counter(words[i])
        if words[i] in one and common_count < 3:
            value += 1
            if best_worst(1):
                if indicator:
                    best_words.append(words[i])
                else:
                    worst_words.append(words[i])
                    
        elif words[i] in two and common_count < 3:
            value += 2
            if best_worst(2):
                if indicator:
                    best_words.append(words[i])
                else:
                    worst_words.append(words[i])
                    
        elif words[i] in three and common_count < 3:
            value += 3
            if best_worst(3):
                if indicator:
                    best_words.append(words[i])
                else:
                    worst_words.append(words[i])
                    
        elif words[i] in four and common_count < 3:
            value += 4
            if best_worst(4):
                if indicator:
                    best_words.append(words[i])
                else:
                    worst_words.append(words[i])
                    
        elif words[i] in five and common_count < 3:
            value += 5
            if best_worst(5):
                if indicator:
                    best_words.append(words[i])
                else:
                    worst_words.append(words[i])
                    
        else:
            length -= 1
        common_words = 0
    
    if length == 0:
        return 'review text does not have significant words'
    score = (value) / length
    
    print('score: ', score)
    print('best used words: ', best_words)
    print('worst used words: ', worst_words)

# %%
test = baby_five['reviewText'][10]

# %%
point_value(test, one_star, two_star, three_star, four_star, five_star)
# Out:
# score:  3.6666666666666665
# best used words:  ['feeding', 'wet', 'pumping', 'feeding']
# worst used words:  ['finally', 'horrible']
